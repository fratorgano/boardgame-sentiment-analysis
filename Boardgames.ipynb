# %% [markdown]
# # What do you like in boardgames
# The goal of this project is to explore the data from boardgamegeek.com and try to discover the most-liked and disliked aspects of each of the top 10 games (as of 25/06/2024)

# %%
import pandas as pd
import requests
import xml.etree.ElementTree as ET
import math
import time
import ast
import string
import pickle
import os.path
import matplotlib.pyplot as plt

import transformers
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification, EarlyStoppingCallback
import torch.nn.functional as F
import fasttext
from setfit import AbsaModel, AbsaTrainer, TrainingArguments
from pyabsa import available_checkpoints, TaskCodeOption, AspectTermExtraction as ATEPC, ModelSaveOption, DeviceTypeOption
from datasets import load_dataset
import simplemma
from nltk.stem import WordNetLemmatizer
import warnings

transformers.logging.set_verbosity_error()

# %%
# loading data from boarggamegeek about boardgames downloaded from boardgamegeek.com (26/06/2024)
df_boardgames = pd.read_csv('./content/drive/MyDrive/Boardgames/boardgames_ranks.csv')

# %%
# keep only the top 10 games, the df is already sorted by highest rated
df_boardgames_10 = df_boardgames[:10]

# %%
def donwload_game_comments(game_id):
    comments=[]
    base_url = f'https://api.geekdo.com/xmlapi2/thing?type=boardgame&id={game_id}&comments=1'
    print(f'Downloading comments for game with id {game_id}')
    r = requests.get(base_url)
    # parse downloaded xml
    root = ET.fromstring(r.content)
    # extract the total number of comments for that game
    number_of_comments = int(root[0].find('comments').attrib['totalitems'])
    # calculate the number of pages to request to download all comments
    number_of_pages = math.ceil(number_of_comments / 100)
    time.sleep(1)
    # download comments from all pages
    for i in range(number_of_pages):
        # create url for the next page
        url = f'{base_url}&page={i+1}'
        while(True):
            r = requests.get(url)
            # parse downloaded xml
            root = ET.fromstring(r.content)
            # iterate over comments to store them
            for comment in root.iter('comment'):
                comment.attrib['boardgame_id'] = game_id
                comments.append(comment.attrib)
            print(f"{len(comments)}/{number_of_comments}")
            time.sleep(1.5)
            if len(list(root.iter('comment')))>0:
                break
            else:
                print('repeating page download since no comment was received')
    # the API does not give comments sometimes, so we check if the number of comments obtained so far matches the expectation
    if len(comments)!=number_of_comments:
        print(f'Failed to download ALL comments for game with id: {game_id}')
    return pd.DataFrame(comments)

# %%
# if reviews are not already downloaded, download them and store them
if not os.path.isfile('./content/drive/MyDrive/Boardgames/boardgames_comments.csv'):
    df_comments = pd.DataFrame()
    for i,boardgame in df_boardgames_10.iterrows():
        df_game_comments = donwload_game_comments(boardgame['id'])
        df_comments = pd.concat([df_comments, df_game_comments])
    df_comments.to_csv('/content/drive/MyDrive/Boardgames/boardgames_comments.csv')
else:
    df_comments = pd.read_csv('./content/drive/MyDrive/Boardgames/boardgames_comments.csv',index_col=0)

# %%
df_comments
# Out:
#               username  rating  \
# 0      1 Family Meeple     NaN
# 1               13inha     NaN
# 2                 1bez    10.0
# 3                 2bit     7.5
# 4                 2d20     9.0
# ...                ...     ...
# 67905        Zvonmirus     7.5
# 67906          Zygomax     NaN
# 67907         _Kenneth     9.5
# 67908            _LSK_     5.0
# 67909           _wolo_     5.0
#
#                                                    value  boardgame_id
# 0      SLEEVED[IMG]https://cf.geekdo-static.com/mbs/m...        224517
# 1                                                      G        224517
# 2      Great game, full controllo of your strategy th...        224517
# 3      Very clever game, enjoyable overall.  Plus poi...        224517
# 4      Brilliant!  Fits right into my wheelhouse all ...        224517
# ...                                                  ...           ...
# 67905  Only played the beginning scenarios with my el...        291457
# 67906                                BGS Prize Nov. 2021        291457
# 67907            Cooperative Legacy (2P-3P) ✓ Completion        291457
# 67908  Too hard under the rules in the game and a bit...        291457
# 67909                              Fiddly and repetitive        291457
#
# [67910 rows x 4 columns]

# %%
def clean_comments(df_comments,length=None):
    df_comments_cleaned = df_comments.copy()
    # make sure comments are strings
    df_comments_cleaned['value'] = df_comments_cleaned['value'].map(lambda value: str(value))
    # initialized model to detect language
    model_lang_detection = fasttext.load_model('./content/drive/MyDrive/Boardgames/lid.176.ftz')
    # add column to dataframe with language
    df_comments_cleaned['lang'] = df_comments_cleaned['value'].map(lambda comment: model_lang_detection.predict(comment, k=1)[0][0].replace('__label__',''))
    # filter dataframe to keep english language only
    df_comments_cleaned = df_comments_cleaned[df_comments_cleaned['lang']=='en']
    # remove short comments, remove bottom 25% elements
    if length==None:
        length = df_comments_cleaned['value'].map(lambda comment: len(comment)).quantile(0.25)
    df_comments_cleaned = df_comments_cleaned[df_comments_cleaned['value'].map(lambda t:len(t)>length)]
    df_comments_cleaned = df_comments_cleaned.reset_index()
    return df_comments_cleaned

# %%
df_comments_only_eng_short = clean_comments(df_comments)
df_comments_only_eng_long = clean_comments(df_comments, length=100)

# %%
# print some elements to use as example in the report
for elem in df_comments_only_eng_short[df_comments_only_eng_short['value'].apply(lambda v: 'luck' in v and len(v)<100)]['value'][:20]:
    print(elem)
# Out:
# Low luck, high skill game which good moves are not obvious and many strategies are viable.
# Great mechanics. Too much luck involved (drawing cards)
# Unluckily I sold it before playing it because I did not have a group to play with.
# Feel like going through the motions alot of chance and luck in this game.
# Great fun but can be very luck dependent.
# players -  2 - 4 rules -    MEDIUM luck -     MEDIUM strategy - HIGH  CO-OP
# A true masterpiece ! I only wish the mechanics were a tiny bit less luck-based.
# Beautiful but too much based on luck
# Nothing else comes close if you like the Card Management system and lack of luck.
# Solo only - a bit too much luck of the drawer for my taste.
# Played on TTS. Preordered. Card luck like Wingspan. Some boards and sponsor powers are broken.
# My initial gripes about the luck factor mostly disappeared the more I played.
# Overhyped. Too much luck involved with drawing of cards.
# too much luck in the cards for the lenght and the complexity of this game
# Variability of the card draw from the giant stack means a long of lucky/unlucky things can happen.
# This was fun. -1.5 because of the luck of the draw and another -0.5 for being frankly a little ugly
# Too dependent on luck of card draw for me.
# Great game, only the luck of the draw knocks it a peg down.
# Overly long and it can be quite lucky. Nothing spectacular about the design at all.
# ok game, we played a rule wrong, which made it feel very lucky.

# %%
# download reviews about everdell and uno to use as ""control variables""
if not os.path.isfile('./content/drive/MyDrive/Boardgames/boardgames_comments_everdell.csv'):
    df_everdell = donwload_game_comments(199792)
else:
    df_everdell = pd.read_csv('./content/drive/MyDrive/Boardgames/boardgames_comments_everdell.csv',index_col=0)

if not os.path.isfile('./content/drive/MyDrive/Boardgames/boardgames_comments_uno.csv'):
    df_uno = donwload_game_comments(2223)
else:
    df_uno = pd.read_csv('./content/drive/MyDrive/Boardgames/boardgames_comments_uno.csv',index_col=0)

# %%
# clean datasets of the newly downloaded games
df_everdell_cleaned = clean_comments(df_everdell)
df_uno_cleaned = clean_comments(df_uno)

# %%
df_boardgames_control = df_boardgames[(df_boardgames['id']==2223)|(df_boardgames['id']==199792)]
df_boardgames_control
# Out:
#            id      name  yearpublished   rank  bayesaverage  average  \
# 34     199792  Everdell           2018     35       7.84704  8.02615
# 26430    2223       UNO           1971  26431       5.33672  5.45676
#
#        usersrated  is_expansion  abstracts_rank  cgs_rank  \
# 34          54686             0             NaN       NaN
# 26430       29135             0             NaN       NaN
#
#        childrensgames_rank  familygames_rank  partygames_rank  \
# 34                     NaN               3.0              NaN
# 26430                  NaN            3179.0              NaN
#
#        strategygames_rank  thematic_rank  wargames_rank
# 34                   40.0            NaN            NaN
# 26430                 NaN            NaN            NaN

# %%
df_boardgames_10_control = pd.concat([df_boardgames_10,df_boardgames_control])

# %% [markdown]
# # Hugging face - Deberta v3 base absa

# %%
# Load Aspect-Based Sentiment Analysis model
absa_tokenizer = AutoTokenizer.from_pretrained("yangheng/deberta-v3-base-absa-v1.1", use_fast=False)
absa_model = AutoModelForSequenceClassification.from_pretrained("yangheng/deberta-v3-base-absa-v1.1")
absa_pipeline = pipeline('text-classification', model=absa_model, tokenizer=absa_tokenizer, max_length=512, truncation=True,device=0)

# %%
def map_row_to_value(row, aspect):
    if row[f'aspect_{aspect}_label']=='Positive':
        return 1
    elif row[f'aspect_{aspect}_label']=='Negative':
        return -1
    elif row[f'aspect_{aspect}_label']=='Neutral':
        return 0
def map_row_to_value2(row, aspect):
    if row[f'aspect_{aspect}_label']=='Positive':
        return row[f'aspect_{aspect}_score']
    elif row[f'aspect_{aspect}_label']=='Negative':
        return -row[f'aspect_{aspect}_score']
    elif row[f'aspect_{aspect}_label']=='Neutral':
        return 0

# %%
aspects = ['luck','bookkeeping','downtime','interaction','bash the leader','complicated','complex']
def analyze_aspects(df_comments, aspects=aspects):
    df_comments_with_aspects = df_comments.copy()
    for aspect in aspects:
        print(f'Analyzing {aspect}')
        results = absa_pipeline(df_comments['value'].to_list(),  text_pair=aspect)
        df_comments_with_aspects[f'aspect_{aspect}'] = results
        df_comments_with_aspects[f'aspect_{aspect}_label'] = [res['label'] for res in results]
        df_comments_with_aspects[f'aspect_{aspect}_score'] = [res['score'] for res in results]
        df_comments_with_aspects[f'aspect_{aspect}_mapped'] = df_comments_with_aspects.apply(lambda row:map_row_to_value(row,aspect),axis=1)
        df_comments_with_aspects[f'aspect_{aspect}_mapped2'] = df_comments_with_aspects.apply(lambda row:map_row_to_value2(row,aspect),axis=1)
    return df_comments_with_aspects

# %%
df_comments_only_eng_short_with_aspects = analyze_aspects(df_comments_only_eng_short)

# %%
df_everdell_with_aspects = analyze_aspects(df_everdell_cleaned)
# Out:
# Analyzing luck
# Analyzing bookkeeping
# Analyzing downtime
# Analyzing interaction
# Analyzing bash the leader
# Analyzing complicated
# Analyzing complex

# %%
df_uno_with_aspects = analyze_aspects(df_uno_cleaned)
# Out:
# Analyzing luck
# Analyzing bookkeeping
# Analyzing downtime
# Analyzing interaction
# Analyzing bash the leader
# Analyzing complicated
# Analyzing complex

# %%
df_comments_only_eng_short_with_aspects.to_csv('/home/fra/uni/nlp/project/content/drive/MyDrive/Boardgames/boardgames_comments_default_aspects.csv')
df_everdell_with_aspects.to_csv('/home/fra/uni/nlp/project/content/drive/MyDrive/Boardgames/boardgames_comments_everdell_default_aspects.csv')
df_uno_with_aspects.to_csv('/home/fra/uni/nlp/project/content/drive/MyDrive/Boardgames/boardgames_comments_uno_default_aspects.csv')

# %%
df_comments_only_eng_short_with_aspects = pd.read_csv('/home/fra/uni/nlp/project/content/drive/MyDrive/Boardgames/boardgames_comments_default_aspects.csv',index_col=0)
df_everdell_with_aspects = pd.read_csv('/home/fra/uni/nlp/project/content/drive/MyDrive/Boardgames/boardgames_comments_everdell_default_aspects.csv',index_col=0)
df_uno_with_aspects = pd.read_csv('/home/fra/uni/nlp/project/content/drive/MyDrive/Boardgames/boardgames_comments_uno_default_aspects.csv',index_col=0)

# %%
# code to fix dictionaries that are stored as string by pd.from_csv 
def fix_dictionaries(row,aspect):
    string_dict = row[f'aspect_{aspect}']
    dict = ast.literal_eval(string_dict)
    return dict
for aspect in aspects:
    srs_dict = df_comments_only_eng_short_with_aspects.apply(lambda row:fix_dictionaries(row,aspect),axis=1)
    df_comments_only_eng_short_with_aspects[f'aspect_{aspect}'] = srs_dict
for aspect in aspects:
    results = df_comments_only_eng_short_with_aspects[f'aspect_{aspect}'].to_list()
    df_comments_only_eng_short_with_aspects[f'aspect_{aspect}_label'] = [res['label'] for res in results]
    df_comments_only_eng_short_with_aspects[f'aspect_{aspect}_score'] = [res['score'] for res in results]
    df_comments_only_eng_short_with_aspects[f'aspect_{aspect}_mapped'] = df_comments_only_eng_short_with_aspects.apply(lambda row:map_row_to_value(row,aspect),axis=1)
    df_comments_only_eng_short_with_aspects[f'aspect_{aspect}_mapped2'] = df_comments_only_eng_short_with_aspects.apply(lambda row:map_row_to_value2(row,aspect),axis=1)

# %%
for boardgame_id in df_boardgames_10['id']:
    boardgame_comments = df_comments_only_eng_short_with_aspects[df_comments_only_eng_short_with_aspects['boardgame_id']==boardgame_id]
    boardgame_data = df_boardgames_10[df_boardgames_10['id']==boardgame_id]
    print(f"{boardgame_data['name'].iloc[0]} ({boardgame_data['id'].iloc[0]})")
    scores = []
    for aspect in aspects:
        boardgame_comments_polars = boardgame_comments
        score1 = boardgame_comments[f'aspect_{aspect}_mapped'].sum()/len(boardgame_comments_polars)
        score2 = boardgame_comments[f'aspect_{aspect}_mapped2'].sum()/len(boardgame_comments_polars)
        scores.append(f'{score1:.2}')
        #print(f"{aspect}:  : {score2:.2}")
    print(' & '.join(scores))
# Out:
# Brass: Birmingham
# 0.37 & 0.26 & 0.31 & 0.41 & 0.24 & -0.4 & 0.095
# Pandemic Legacy: Season 1
# 0.34 & 0.24 & 0.33 & 0.39 & 0.21 & -0.33 & 0.1
# Gloomhaven
# 0.29 & 0.17 & 0.22 & 0.3 & 0.17 & -0.42 & -0.0082
# Ark Nova
# 0.24 & 0.2 & 0.18 & 0.25 & 0.16 & -0.4 & 0.034
# Twilight Imperium: Fourth Edition
# 0.32 & 0.21 & 0.2 & 0.33 & 0.17 & -0.44 & 0.033
# Dune: Imperium
# 0.38 & 0.31 & 0.37 & 0.42 & 0.3 & -0.26 & 0.22
# Terraforming Mars
# 0.28 & 0.2 & 0.22 & 0.29 & 0.17 & -0.4 & 0.063
# War of the Ring: Second Edition
# 0.38 & 0.28 & 0.32 & 0.42 & 0.24 & -0.42 & 0.073
# Star Wars: Rebellion
# 0.38 & 0.29 & 0.32 & 0.42 & 0.25 & -0.33 & 0.13
# Gloomhaven: Jaws of the Lion
# 0.35 & 0.25 & 0.33 & 0.4 & 0.23 & -0.38 & 0.038

# %%
print("UNO")
scores = []
for aspect in aspects:
    boardgame_comments_polars = df_uno_with_aspects
    score1 = df_uno_with_aspects[f'aspect_{aspect}_mapped'].sum()/len(boardgame_comments_polars)
    score2 = df_uno_with_aspects[f'aspect_{aspect}_mapped2'].sum()/len(boardgame_comments_polars)
    print(f"{aspect}: {score1} - {score2}")
    scores.append(f'{score1:.2}')
print(' & '.join(scores))
# Out:
# UNO
# luck: 0.12915234822451319 - 0.08718912821489239
# bookkeeping: 0.036368843069874 - 0.028064031567838457
# downtime: 0.12371134020618557 - 0.09373746944627674
# interaction: 0.14461626575028638 - 0.11044979105700332
# bash the leader: -0.06786941580756013 - -0.053911250592438766
# complicated: -0.6660939289805269 - -0.5434149868982627
# complex: -0.16237113402061856 - -0.1334041057566324
# 0.13 & 0.036 & 0.12 & 0.14 & -0.068 & -0.67 & -0.16

# %%
print("Everdell")
scores = []
for aspect in aspects:
    boardgame_comments_polars = df_everdell_with_aspects
    score1 = df_everdell_with_aspects[f'aspect_{aspect}_mapped'].sum()/len(boardgame_comments_polars)
    score2 = df_everdell_with_aspects[f'aspect_{aspect}_mapped2'].sum()/len(boardgame_comments_polars)
    print(f"{aspect}: {score1} - {score2}")
    scores.append(f'{score1:.2}')
print(' & '.join(scores))
# Out:
# Everdell
# luck: 0.39028658936775323 - 0.3163189872809193
# bookkeeping: 0.3218114198206082 - 0.2649124281473166
# downtime: 0.37716035878363596 - 0.3226796336858337
# interaction: 0.42375847735725225 - 0.36864200744266923
# bash the leader: 0.30781010719754975 - 0.25930177459985937
# complicated: -0.23911616714066944 - -0.19680007381372447
# complex: 0.20017501640778823 - 0.16144633592413854
# 0.39 & 0.32 & 0.38 & 0.42 & 0.31 & -0.24 & 0.2

# %% [markdown]
# # Setfit ABSA

# %% [markdown]
# ## Pretrained

# %%
# Download from the 🤗 Hub
model = AbsaModel.from_pretrained(
    "tomaarsen/setfit-absa-bge-small-en-v1.5-restaurants-aspect",
    "tomaarsen/setfit-absa-bge-small-en-v1.5-restaurants-polarity",
)
# Out:
# /home/fra/.venv/nlp/lib/python3.10/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.3.2 when using version 1.4.1.post1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
game_aspects = {}
for boardgame_id in df_boardgames_10['id']:
    boardgame_comments = df_comments_only_eng_short[df_comments_only_eng_short['boardgame_id']==boardgame_id]
    boardgame_data = df_boardgames_10[df_boardgames_10['id']==boardgame_id]
    print(f"{boardgame_data['name'].iloc[0]} ({boardgame_data['id'].iloc[0]})")
    aspects=[]
    polarities=[]
    for comment in boardgame_comments['value']:
        aspect_prediction = model(comment)
        for elem in aspect_prediction:
            if isinstance(elem, dict):
                aspects.append(elem['span'])
                polarities.append(elem['polarity'])
    game_aspects[f'{boardgame_id}'] = (aspects, polarities)
# Out:
# Brass: Birmingham
# Pandemic Legacy: Season 1
# Gloomhaven
# Ark Nova
# Twilight Imperium: Fourth Edition
# Dune: Imperium
# Terraforming Mars
# War of the Ring: Second Edition
# Star Wars: Rebellion
# Gloomhaven: Jaws of the Lion

# %%
game_aspects_long = {}
for boardgame_id in df_boardgames_10['id']:
    boardgame_comments = df_comments_only_eng_long[df_comments_only_eng_long['boardgame_id']==boardgame_id]
    boardgame_data = df_boardgames_10[df_boardgames_10['id']==boardgame_id]
    print(f"{boardgame_data['name'].iloc[0]} ({boardgame_data['id'].iloc[0]})")
    aspects=[]
    polarities=[]
    for comment in boardgame_comments['value']:
        aspect_prediction = model(comment)
        for elem in aspect_prediction:
            if isinstance(elem, dict):
                aspects.append(elem['span'])
                polarities.append(elem['polarity'])
    game_aspects[f'{boardgame_id}'] = (aspects, polarities)
# Out:
# Brass: Birmingham
# Pandemic Legacy: Season 1
# Gloomhaven
# Ark Nova
# Twilight Imperium: Fourth Edition
# Dune: Imperium
# Terraforming Mars
# War of the Ring: Second Edition
# Star Wars: Rebellion
# Gloomhaven: Jaws of the Lion

# %%
# uno
aspects=[]
polarities=[]
boardgame_id='2223'
for comment in df_uno_cleaned['value']:
    aspect_prediction = model(comment)
    for elem in aspect_prediction:
        if isinstance(elem, dict):
            aspects.append(elem['span'])
            polarities.append(elem['polarity'])
(aspects, polarities)
game_aspects[f'{boardgame_id}'] = (aspects, polarities)

# %%
# everdell
aspects=[]
polarities=[]
boardgame_id='199792'
for comment in df_everdell_cleaned['value']:
    aspect_prediction = model(comment)
    for elem in aspect_prediction:
        if isinstance(elem, dict):
            aspects.append(elem['span'])
            polarities.append(elem['polarity'])
game_aspects[f'{boardgame_id}'] = (aspects, polarities)

# %%
try:
    game_aspects
    with open('/home/fra/uni/nlp/project/content/drive/MyDrive/Boardgames/saved_game_aspects_dict.pkl','wb') as f:
        pickle.dump(game_aspects, f)
except NameError:
    print('loaded from storage')
    with open('/home/fra/uni/nlp/project/content/drive/MyDrive/Boardgames/saved_game_aspects_dict.pkl', 'rb') as f:
        game_aspects = pickle.load(f)
# Out:
# loaded from storage

# %%
try:
    game_aspects_long
    with open('/home/fra/uni/nlp/project/content/drive/MyDrive/Boardgames/saved_game_aspects_long_dict.pkl','wb') as f:
        pickle.dump(game_aspects_long, f)
except NameError:
    print('loaded from storage')
    with open('/home/fra/uni/nlp/project/content/drive/MyDrive/Boardgames/saved_game_aspects_long_dict.pkl', 'rb') as f:
        game_aspects_long = pickle.load(f)
# Out:
# loading from storage

# %%
# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()
def extract_list(game_aspects, min_cutoff=20, n_aspects=10, lemmatization=False):
    for boardgame_id in df_boardgames_10_control['id'].to_list():
        boardgame_data = df_boardgames_10_control[df_boardgames_10_control['id']==boardgame_id]
        filtered_words = ['game','games','Game','Games']
        if(not boardgame_data.empty):
            print(f"{boardgame_data['name'].iloc[0]} ({boardgame_data['id'].iloc[0]})")
            filtered_words.append(boardgame_data['name'].iloc[0])
            name_without_punct = boardgame_data['name'].iloc[0].translate(str.maketrans('', '', string.punctuation))
            filtered_words += name_without_punct.lower().split(' ')
        print(filtered_words)
        srs_aspects = pd.Series(game_aspects[f'{boardgame_id}'][0])
        srs_polarities = pd.Series(game_aspects[f'{boardgame_id}'][1])
        if lemmatization:
            srs_aspects = srs_aspects.apply(lambda aspect:lemmatizer.lemmatize(aspect))
            #srs_aspects = srs_aspects.apply(lambda aspect:simplemma.lemmatize(aspect,lang='en'))
        generated_aspects = pd.DataFrame()
        generated_aspects['id'] = [boardgame_id for _ in range(len(srs_aspects))]
        generated_aspects['aspects'] = srs_aspects.apply(lambda x:x.lower())
        generated_aspects['polarities'] = srs_polarities.apply(lambda x:x.lower())
        generated_aspects_filtered = generated_aspects[~generated_aspects['aspects'].isin(filtered_words)]
        #generated_aspects_all = pd.concat([generated_aspects_all, generated_aspects])
        # consider only aspects with at least 20 observations
        valid_aspects = generated_aspects_filtered['aspects'].value_counts()
        valid_aspects = valid_aspects[valid_aspects>=min_cutoff].index
        #print(valid_aspects)
        results = []
        for aspect in valid_aspects:
            aspect_polarities = generated_aspects_filtered[generated_aspects_filtered['aspects']==aspect]['polarities']
            positive_aspect_count = aspect_polarities.where(lambda v:v=='positive').count()
            negative_aspect_count = aspect_polarities.where(lambda v:v=='negative').count()
            neutral_aspect_count = aspect_polarities.where(lambda v:v=='neutral').count()
            score = (positive_aspect_count-negative_aspect_count)/len(aspect_polarities)
            #print(f'{aspect}: {positive_aspect_count}, {negative_aspect_count}, {neutral_aspect_count} -> {score}')
            results.append((aspect,positive_aspect_count,negative_aspect_count,neutral_aspect_count,score))
        scores = [res[4] for res in results]
        aspects = [res[0] for res in results]
        df_aspect_score = pd.DataFrame()
        df_aspect_score['aspect'] = aspects
        df_aspect_score['score'] = scores
        n_aspects = n_aspects if len(aspects)>n_aspects*2 else len(aspects)//2
        print(n_aspects)
        print(f"Best: {df_aspect_score.sort_values(by=['score'],ascending=False)['aspect'][:n_aspects].to_list()}")
        print(f"Worst: {df_aspect_score.sort_values(by=['score'],ascending=True)['aspect'][:n_aspects].to_list()}")
        print('\n')

# %%
extract_list(game_aspects, n_aspects=10, min_cutoff=25, lemmatization=True)
# Out:
# Brass: Birmingham (224517)
# ['game', 'games', 'Game', 'Games', 'Brass: Birmingham', 'brass', 'birmingham']
# 10
# Best: ['martin wallace', 'weight', 'iron clays', 'player interaction', 'location', 'production', 'deluxe edition', 'interaction', 'economy', 'masterpiece']
# Worst: ['work', 'downtime', 'score', 'taste', 'hype', 'reason', 'move', 'luck', 'rating', 'connection']
#
#
# Pandemic Legacy: Season 1 (161936)
# ['game', 'games', 'Game', 'Games', 'Pandemic Legacy: Season 1', 'pandemic', 'legacy', 'season', '1']
# 10
# Best: ['board game experience', 'gaming experiences', 'co-op game', 'journey', 'gaming experience', 'adventure', 'legacy aspects', 'ride', 'legacy experience', 'love']
# Worst: ['chore', 'taste', 'mistake', 'ending', 'replay', 'player game', 'interest', 'desire', 'deck', 'quarterbacking']
#
#
# Gloomhaven (174430)
# ['game', 'games', 'Game', 'Games', 'Gloomhaven', 'gloomhaven']
# 10
# Best: ['masterpiece', 'downside', 'variety', 'beast', 'replayability', 'leveling', 'depth', 'character classes', 'location', 'legacy elements']
# Worst: ['slog', 'pain', 'desire', 'chore', 'bookkeeping', 'trade', 'taste', 'admin', 'grind', 'interest']
#
#
# Ark Nova (342942)
# ['game', 'games', 'Game', 'Games', 'Ark Nova', 'ark', 'nova']
# 10
# Best: ['marine worlds', 'marine worlds expansion', 'replayability', 'action selection system', 'variety', 'zoo map pack', 'players', 'combination', 'action selection', 'euro game']
# Worst: ['bgg', 'rulebook', 'beginning', 'play time', 'place', 'randomness', 'issue', 'player interaction', 'chance', 'break']
#
#
# Twilight Imperium: Fourth Edition (233078)
# ['game', 'games', 'Game', 'Games', 'Twilight Imperium: Fourth Edition', 'twilight', 'imperium', 'fourth', 'edition']
# 10
# Best: ['story', 'replayability', 'role', 'player interaction', 'improvement', 'alliance', 'epic', 'kings', 'diplomacy', 'prophecy']
# Worst: ['downtime', 'luck', 'randomness', 'rating', 'stuff', 'card', 'tech tree', 'resource', 'goal', 'mechanism']
#
#
# Dune: Imperium (316554)
# ['game', 'games', 'Game', 'Games', 'Dune: Imperium', 'dune', 'imperium']
# 10
# Best: ['jessica', 'depth', 'combination', 'ix', 'blend', 'rise', 'immortality', 'board game', 'replayability', 'ix expansion']
# Worst: ['problem', 'intrigue deck', 'hype', 'issue', 'luck', 'part', 'chance', 'order', 'idea', 'randomness']
#
#
# Terraforming Mars (167791)
# ['game', 'games', 'Game', 'Games', 'Terraforming Mars', 'terraforming', 'mars']
# 10
# Best: ['big box', 'must', 'oxygen level', 'competition', 'favorite', 'promo', 'elysium', 'level', 'colonies', 'hellas']
# Worst: ['downtime', 'agricola', 'problem', 'production quality', 'price', 'graphic', 'solitaire', 'icon', 'attention', 'leader']
#
#
# War of the Ring: Second Edition (115746)
# ['game', 'games', 'Game', 'Games', 'War of the Ring: Second Edition', 'war', 'of', 'the', 'ring', 'second', 'edition']
# 10
# Best: ['narrative', 'depth', 'warriors', 'story', 'middle', 'tension', 'lord', 'epic', 'lords', 'masterpiece']
# Worst: ['hour', 'rulebook', 'luck', 'setup', 'rebellion', 'risk', 'bit', 'rating', 'rule book', 'rule']
#
#
# Star Wars: Rebellion (187645)
# ['game', 'games', 'Game', 'Games', 'Star Wars: Rebellion', 'star', 'wars', 'rebellion']
# 10
# Best: ['rise', 'element', 'game mechanics', 'feel', 'trilogy', 'epic', 'experience', 'empire expansion', 'star wars trilogy', 'moment']
# Worst: ['combat system', 'dice', 'rating', 'bit', 'table', 'ship', 'ffg', 'luck', 'team', 'play time']
#
#
# Gloomhaven: Jaws of the Lion (291457)
# ['game', 'games', 'Game', 'Games', 'Gloomhaven: Jaws of the Lion', 'gloomhaven', 'jaws', 'of', 'the', 'lion']
# 10
# Best: ['intro', 'introduction', 'improvement', 'job', 'class', 'fun', 'gloomhaven system', 'gloomhaven universe', 'wife', 'value']
# Worst: ['interest', 'action', 'upkeep', 'turn', 'monster', 'dice', 'card', 'fan', 'damage', 'mission']
#
#
# Everdell (199792)
# ['game', 'games', 'Game', 'Games', 'Everdell', 'everdell']
# 10
# Best: ['art work', 'favorite', 'spirecrest', 'victory', 'love', 'hand management', 'table presence', 'newleaf', 'aesthetic', 'town']
# Worst: ['text', 'hype', 'card draw', 'font', 'downtime', 'cardboard tree', 'imperial settlers', 'problem', 'rating', 'draw']
#
#
# UNO (2223)
# ['game', 'games', 'Game', 'Games', 'UNO', 'uno']
# 10
# Best: ['fun game', 'classic', 'fun', 'friend', 'family game', 'party game', 'group', 'lot', 'family', 'crazy eights']
# Worst: ['decision', 'strategy', 'skill', 'rating', 'luck', 'turn', 'copy', 'play', 'table', 'card']

# %% [markdown]
# # PyABSA - Fast LCF
# https://www.mdpi.com/2076-3417/9/16/3389

# %%
config = (
    ATEPC.ATEPCConfigManager.get_atepc_config_english()
)  # this config contains 'pretrained_bert', it is based on pretrained models
config.model = ATEPC.ATEPCModelList.FAST_LCF_ATEPC  # improved version of LCF-ATEPC

# %%
dataset = ATEPC.ATEPCDatasetList.Restaurant14

# %%
warnings.filterwarnings("ignore")

config.batch_size = 16
config.patience = 2
config.log_step = -1
config.seed = [1]
config.verbose = False  # If verbose == True, PyABSA will output the model strcture and seversal processed data examples
config.notice = (
    "This is an training example for aspect term extraction"  # for memos usage
)

trainer = ATEPC.ATEPCTrainer(
    config=config,
    dataset=dataset,
    from_checkpoint="english",  # if you want to resume training from our pretrained checkpoints, you can pass the checkpoint name here
    auto_device=DeviceTypeOption.AUTO,  # use cuda if available
    checkpoint_save_mode=ModelSaveOption.SAVE_MODEL_STATE_DICT,  # save state dict only instead of the whole model
    load_aug=False,  # there are some augmentation dataset for integrated datasets, you use them by setting load_aug=True to improve performance
)
# Out:
# [2024-07-04 14:12:49] (2.4.1.post1) Set Model Device: cuda:0
# [2024-07-04 14:12:49] (2.4.1.post1) Device Name: NVIDIA GeForce GTX 1070
# config.json:   0%|          | 0.00/579 [00:00<?, ?B/s]
# 2024-07-04 14:12:49,956 INFO: PyABSA version: 2.4.1.post1
# 2024-07-04 14:12:49,958 INFO: Transformers version: 4.42.3
# 2024-07-04 14:12:49,959 INFO: Torch version: 2.3.1+cu121+cuda12.1
# 2024-07-04 14:12:49,961 INFO: Device: NVIDIA GeForce GTX 1070
# 2024-07-04 14:12:49,989 INFO: Searching dataset 114.Restaurant14 in https://github.com/yangheng95/ABSADatasets
# [2024-07-04 14:12:49] (2.4.1.post1) Clone ABSADatasets from https://github.com/yangheng95/ABSADatasets.git
# 2024-07-04 14:12:59,978 INFO: You can set load_aug=True in a trainer to augment your dataset (English only yet) and improve performance.
# 2024-07-04 14:12:59,979 INFO: Please use a new folder to perform new text augment if the former augment in integrated_datasets/atepc_datasets/110.SemEval/114.restaurant14 errored unexpectedly
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# [2024-07-04 14:13:02] (2.4.1.post1) Can not load en_core_web_sm from spacy, try to download it in order to parse syntax tree:
# python -m spacy download en_core_web_sm
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: setuptools in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (59.6.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: jinja2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: numpy>=1.19.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.3)
# Requirement already satisfied: packaging>=20.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.0)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.10.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# convert examples to features:  16%|█▋        | 589/3608 [00:00<00:03, 865.03it/s]
# 2024-07-04 14:13:10,638 WARNING: AspectTooLongWarning -> <aspect: fried mini buns with the condensed milk and the assorted fruits on beancurd> is too long, <text: The waitress remembers me and is very friendly , she knows what my regular is and that ' s the fried mini buns with the condensed milk and the assorted fruits on beancurd .>, <polarity: Positive>
# convert examples to features:  47%|████▋     | 1680/3608 [00:02<00:02, 837.98it/s]
# 2024-07-04 14:13:12,038 WARNING: AspectTooLongWarning -> <aspect: salad with perfectly marinated cucumbers and tomatoes with lots of shrimp and basil> is too long, <text: I ate clams oreganta and spectacular salad with perfectly marinated cucumbers and tomatoes with lots of shrimp and basil .>, <polarity: Positive>
# convert examples to features:  56%|█████▌    | 2022/3608 [00:02<00:01, 822.76it/s]
# 2024-07-04 14:13:12,410 WARNING: AspectTooLongWarning -> <aspect: Godmother pizza ( a sort of traditional flat pizza with an olive oil - brushed crust and less tomato sauce than usual )> is too long, <text: But they ' ve done a really nice job of offering all the typical pizzeria faves plus some terrific specials like the Godmother pizza ( a sort of traditional flat pizza with an olive oil - brushed crust and less tomato sauce than usual ) .>, <polarity: Positive>
# convert examples to features:  89%|████████▉ | 3226/3608 [00:03<00:00, 838.44it/s]
# 2024-07-04 14:13:13,930 WARNING: AspectTooLongWarning -> <aspect: egg noodles in the beef broth with shrimp dumplings and slices of BBQ roast pork> is too long, <text: I fell in love with the egg noodles in the beef broth with shrimp dumplings and slices of BBQ roast pork .>, <polarity: Positive>
# convert examples to features: 100%|██████████| 3608/3608 [00:04<00:00, 810.49it/s]
# 2024-07-04 14:13:14,326 INFO: Dataset Label Details: {'Neutral': 637, 'Negative': 807, 'Positive': 2160, 'Sum': 3604}
# convert examples to features:  50%|█████     | 563/1120 [00:00<00:00, 902.64it/s]
# 2024-07-04 14:13:15,567 WARNING: AspectTooLongWarning -> <aspect: Mediterranean salads - - layered with beets , goat cheese and walnuts> is too long, <text: Generously garnished , organic grilled burgers are the most popular dish , but the Jerusalem market - style falafel wraps and Mediterranean salads - - layered with beets , goat cheese and walnuts - - are equally scrumptious .>, <polarity: Positive>
# convert examples to features:  98%|█████████▊| 1092/1120 [00:01<00:00, 761.54it/s]
# 2024-07-04 14:13:16,261 WARNING: AspectTooLongWarning -> <aspect: Greek yogurt ( with cuccumber , dill , and garlic )> is too long, <text: Creamy appetizers - - taramasalata , eggplant salad , and Greek yogurt ( with cuccumber , dill , and garlic ) taste excellent when on warm pitas .>, <polarity: Positive>
# convert examples to features: 100%|██████████| 1120/1120 [00:01<00:00, 828.81it/s]
# 2024-07-04 14:13:16,263 INFO: Dataset Label Details: {'Neutral': 196, 'Negative': 196, 'Positive': 726, 'Sum': 1118}
# pytorch_model.bin:   0%|          | 0.00/371M [00:00<?, ?B/s]
# 2024-07-04 14:13:55,046 INFO: Save cache dataset to fast_lcf_atepc.Restaurant14.dataset.3180c1a8d9b4b975f1c495da780d0298592e143b1cb505f57bc6ff1965589266.cache
# 2024-07-04 14:13:55,624 INFO: cuda memory allocated:764963840
# 2024-07-04 14:13:55,625 INFO: ABSADatasetsVersion:None	-->	Calling Count:0
# 2024-07-04 14:13:55,626 INFO: IOB_label_to_index:{'B-ASP': 1, 'I-ASP': 2, 'O': 3, '[CLS]': 4, '[SEP]': 5}	-->	Calling Count:1
# 2024-07-04 14:13:55,628 INFO: MV:<metric_visualizer.metric_visualizer.MetricVisualizer object at 0x7fa93cd207f0>	-->	Calling Count:0
# 2024-07-04 14:13:55,630 INFO: PyABSAVersion:2.4.1.post1	-->	Calling Count:1
# 2024-07-04 14:13:55,631 INFO: SRD:3	-->	Calling Count:9444
# 2024-07-04 14:13:55,632 INFO: TorchVersion:2.3.1+cu121+cuda12.1	-->	Calling Count:1
# 2024-07-04 14:13:55,635 INFO: TransformersVersion:4.42.3	-->	Calling Count:1
# 2024-07-04 14:13:55,636 INFO: auto_device:True	-->	Calling Count:3
# 2024-07-04 14:13:55,637 INFO: batch_size:16	-->	Calling Count:4
# 2024-07-04 14:13:55,638 INFO: cache_dataset:True	-->	Calling Count:1
# 2024-07-04 14:13:55,639 INFO: checkpoint_save_mode:1	-->	Calling Count:4
# 2024-07-04 14:13:55,641 INFO: cross_validate_fold:-1	-->	Calling Count:0
# 2024-07-04 14:13:55,642 INFO: dataset_file:{'train': ['integrated_datasets/atepc_datasets/110.SemEval/114.restaurant14/Restaurants_Train.xml.seg.atepc'], 'test': ['integrated_datasets/atepc_datasets/110.SemEval/114.restaurant14/Restaurants_Test_Gold.xml.seg.atepc'], 'valid': []}	-->	Calling Count:6
# 2024-07-04 14:13:55,642 INFO: dataset_name:Restaurant14	-->	Calling Count:3
# 2024-07-04 14:13:55,644 INFO: device:cuda:0	-->	Calling Count:4
# 2024-07-04 14:13:55,645 INFO: device_name:NVIDIA GeForce GTX 1070	-->	Calling Count:1
# 2024-07-04 14:13:55,647 INFO: dropout:0.5	-->	Calling Count:1
# 2024-07-04 14:13:55,649 INFO: dynamic_truncate:True	-->	Calling Count:9444
# 2024-07-04 14:13:55,650 INFO: embed_dim:768	-->	Calling Count:0
# 2024-07-04 14:13:55,651 INFO: evaluate_begin:0	-->	Calling Count:0
# 2024-07-04 14:13:55,651 INFO: from_checkpoint:english	-->	Calling Count:0
# 2024-07-04 14:13:55,653 INFO: gradient_accumulation_steps:1	-->	Calling Count:3
# 2024-07-04 14:13:55,654 INFO: hidden_dim:768	-->	Calling Count:6
# 2024-07-04 14:13:55,655 INFO: index_to_IOB_label:{1: 'B-ASP', 2: 'I-ASP', 3: 'O', 4: '[CLS]', 5: '[SEP]'}	-->	Calling Count:0
# 2024-07-04 14:13:55,657 INFO: index_to_label:{0: 'Negative', 1: 'Neutral', 2: 'Positive'}	-->	Calling Count:2
# 2024-07-04 14:13:55,658 INFO: inference_model:None	-->	Calling Count:0
# 2024-07-04 14:13:55,659 INFO: initializer:xavier_uniform_	-->	Calling Count:0
# 2024-07-04 14:13:55,661 INFO: l2reg:1e-05	-->	Calling Count:2
# 2024-07-04 14:13:55,662 INFO: label_list:['B-ASP', 'I-ASP', 'O', '[CLS]', '[SEP]']	-->	Calling Count:1
# 2024-07-04 14:13:55,663 INFO: label_to_index:{'Negative': 0, 'Neutral': 1, 'Positive': 2}	-->	Calling Count:0
# 2024-07-04 14:13:55,666 INFO: lcf:cdw	-->	Calling Count:0
# 2024-07-04 14:13:55,667 INFO: learning_rate:2e-05	-->	Calling Count:1
# 2024-07-04 14:13:55,670 INFO: load_aug:False	-->	Calling Count:1
# 2024-07-04 14:13:55,671 INFO: log_step:-1	-->	Calling Count:0
# 2024-07-04 14:13:55,672 INFO: logger:<Logger fast_lcf_atepc (INFO)>	-->	Calling Count:15
# 2024-07-04 14:13:55,674 INFO: max_seq_len:80	-->	Calling Count:33056
# 2024-07-04 14:13:55,676 INFO: model:<class 'pyabsa.tasks.AspectTermExtraction.models.__lcf__.fast_lcf_atepc.FAST_LCF_ATEPC'>	-->	Calling Count:5
# 2024-07-04 14:13:55,678 INFO: model_name:fast_lcf_atepc	-->	Calling Count:4724
# 2024-07-04 14:13:55,679 INFO: model_path_to_save:checkpoints	-->	Calling Count:3
# 2024-07-04 14:13:55,680 INFO: notice:This is an training example for aspect term extraction	-->	Calling Count:0
# 2024-07-04 14:13:55,681 INFO: num_epoch:10	-->	Calling Count:1
# 2024-07-04 14:13:55,683 INFO: num_labels:6	-->	Calling Count:2
# 2024-07-04 14:13:55,684 INFO: optimizer:adamw	-->	Calling Count:2
# 2024-07-04 14:13:55,685 INFO: output_dim:3	-->	Calling Count:1
# 2024-07-04 14:13:55,686 INFO: overwrite_cache:False	-->	Calling Count:0
# 2024-07-04 14:13:55,690 INFO: path_to_save:None	-->	Calling Count:1
# 2024-07-04 14:13:55,690 INFO: patience:2	-->	Calling Count:0
# 2024-07-04 14:13:55,691 INFO: pretrained_bert:microsoft/deberta-v3-base	-->	Calling Count:5
# 2024-07-04 14:13:55,692 INFO: save_mode:1	-->	Calling Count:0
# 2024-07-04 14:13:55,694 INFO: seed:1	-->	Calling Count:6
# 2024-07-04 14:13:55,695 INFO: sep_indices:2	-->	Calling Count:0
# 2024-07-04 14:13:55,698 INFO: show_metric:False	-->	Calling Count:0
# 2024-07-04 14:13:55,699 INFO: spacy_model:en_core_web_sm	-->	Calling Count:7
# 2024-07-04 14:13:55,701 INFO: srd_alignment:True	-->	Calling Count:0
# 2024-07-04 14:13:55,703 INFO: task_code:ATEPC	-->	Calling Count:1
# 2024-07-04 14:13:55,704 INFO: task_name:Aspect Term Extraction and Polarity Classification	-->	Calling Count:0
# 2024-07-04 14:13:55,710 INFO: use_amp:False	-->	Calling Count:1
# 2024-07-04 14:13:55,712 INFO: use_bert_spc:True	-->	Calling Count:0
# 2024-07-04 14:13:55,714 INFO: use_syntax_based_SRD:False	-->	Calling Count:4722
# 2024-07-04 14:13:55,715 INFO: verbose:False	-->	Calling Count:0
# 2024-07-04 14:13:55,717 INFO: warmup_step:-1	-->	Calling Count:0
# 2024-07-04 14:13:55,719 INFO: window:lr	-->	Calling Count:0
# 2024-07-04 14:13:55,725 INFO: cuda memory allocated:764963840
# 2024-07-04 14:13:55,728 INFO: ABSADatasetsVersion:None	-->	Calling Count:0
# 2024-07-04 14:13:55,732 INFO: IOB_label_to_index:{'B-ASP': 1, 'I-ASP': 2, 'O': 3, '[CLS]': 4, '[SEP]': 5}	-->	Calling Count:1
# 2024-07-04 14:13:55,733 INFO: MV:<metric_visualizer.metric_visualizer.MetricVisualizer object at 0x7fa93cd207f0>	-->	Calling Count:0
# 2024-07-04 14:13:55,734 INFO: PyABSAVersion:2.4.1.post1	-->	Calling Count:1
# 2024-07-04 14:13:55,736 INFO: SRD:3	-->	Calling Count:9444
# 2024-07-04 14:13:55,737 INFO: TorchVersion:2.3.1+cu121+cuda12.1	-->	Calling Count:1
# 2024-07-04 14:13:55,739 INFO: TransformersVersion:4.42.3	-->	Calling Count:1
# 2024-07-04 14:13:55,740 INFO: auto_device:True	-->	Calling Count:4
# 2024-07-04 14:13:55,749 INFO: batch_size:16	-->	Calling Count:4
# 2024-07-04 14:13:55,751 INFO: cache_dataset:True	-->	Calling Count:1
# 2024-07-04 14:13:55,752 INFO: checkpoint_save_mode:1	-->	Calling Count:4
# 2024-07-04 14:13:55,754 INFO: cross_validate_fold:-1	-->	Calling Count:1
# 2024-07-04 14:13:55,755 INFO: dataset_file:{'train': ['integrated_datasets/atepc_datasets/110.SemEval/114.restaurant14/Restaurants_Train.xml.seg.atepc'], 'test': ['integrated_datasets/atepc_datasets/110.SemEval/114.restaurant14/Restaurants_Test_Gold.xml.seg.atepc'], 'valid': []}	-->	Calling Count:6
# 2024-07-04 14:13:55,756 INFO: dataset_name:Restaurant14	-->	Calling Count:3
# 2024-07-04 14:13:55,758 INFO: device:cuda:0	-->	Calling Count:8
# 2024-07-04 14:13:55,759 INFO: device_name:NVIDIA GeForce GTX 1070	-->	Calling Count:1
# 2024-07-04 14:13:55,761 INFO: dropout:0.5	-->	Calling Count:1
# 2024-07-04 14:13:55,762 INFO: dynamic_truncate:True	-->	Calling Count:9444
# 2024-07-04 14:13:55,766 INFO: embed_dim:768	-->	Calling Count:0
# 2024-07-04 14:13:55,773 INFO: evaluate_begin:0	-->	Calling Count:0
# 2024-07-04 14:13:55,774 INFO: from_checkpoint:english	-->	Calling Count:0
# 2024-07-04 14:13:55,776 INFO: gradient_accumulation_steps:1	-->	Calling Count:3
# 2024-07-04 14:13:55,777 INFO: hidden_dim:768	-->	Calling Count:6
# 2024-07-04 14:13:55,778 INFO: index_to_IOB_label:{1: 'B-ASP', 2: 'I-ASP', 3: 'O', 4: '[CLS]', 5: '[SEP]'}	-->	Calling Count:0
# 2024-07-04 14:13:55,779 INFO: index_to_label:{0: 'Negative', 1: 'Neutral', 2: 'Positive'}	-->	Calling Count:2
# 2024-07-04 14:13:55,780 INFO: inference_model:None	-->	Calling Count:0
# 2024-07-04 14:13:55,781 INFO: initializer:xavier_uniform_	-->	Calling Count:0
# 2024-07-04 14:13:55,782 INFO: l2reg:1e-05	-->	Calling Count:2
# 2024-07-04 14:13:55,783 INFO: label_list:['B-ASP', 'I-ASP', 'O', '[CLS]', '[SEP]']	-->	Calling Count:1
# 2024-07-04 14:13:55,784 INFO: label_to_index:{'Negative': 0, 'Neutral': 1, 'Positive': 2}	-->	Calling Count:0
# 2024-07-04 14:13:55,785 INFO: lcf:cdw	-->	Calling Count:0
# 2024-07-04 14:13:55,788 INFO: learning_rate:2e-05	-->	Calling Count:1
# 2024-07-04 14:13:55,788 INFO: load_aug:False	-->	Calling Count:1
# 2024-07-04 14:13:55,789 INFO: log_step:-1	-->	Calling Count:0
# 2024-07-04 14:13:55,792 INFO: logger:<Logger fast_lcf_atepc (INFO)>	-->	Calling Count:15
# 2024-07-04 14:13:55,793 INFO: max_seq_len:80	-->	Calling Count:33056
# 2024-07-04 14:13:55,794 INFO: model:<class 'pyabsa.tasks.AspectTermExtraction.models.__lcf__.fast_lcf_atepc.FAST_LCF_ATEPC'>	-->	Calling Count:5
# 2024-07-04 14:13:55,796 INFO: model_name:fast_lcf_atepc	-->	Calling Count:4724
# 2024-07-04 14:13:55,797 INFO: model_path_to_save:checkpoints	-->	Calling Count:3
# 2024-07-04 14:13:55,798 INFO: notice:This is an training example for aspect term extraction	-->	Calling Count:0
# 2024-07-04 14:13:55,799 INFO: num_epoch:10	-->	Calling Count:1
# 2024-07-04 14:13:55,801 INFO: num_labels:6	-->	Calling Count:2
# 2024-07-04 14:13:55,802 INFO: optimizer:adamw	-->	Calling Count:2
# 2024-07-04 14:13:55,803 INFO: output_dim:3	-->	Calling Count:1
# 2024-07-04 14:13:55,806 INFO: overwrite_cache:False	-->	Calling Count:0
# 2024-07-04 14:13:55,807 INFO: path_to_save:None	-->	Calling Count:1
# 2024-07-04 14:13:55,809 INFO: patience:2	-->	Calling Count:0
# 2024-07-04 14:13:55,819 INFO: pretrained_bert:microsoft/deberta-v3-base	-->	Calling Count:5
# 2024-07-04 14:13:55,822 INFO: save_mode:1	-->	Calling Count:0
# 2024-07-04 14:13:55,823 INFO: seed:1	-->	Calling Count:6
# 2024-07-04 14:13:55,827 INFO: sep_indices:2	-->	Calling Count:0
# 2024-07-04 14:13:55,828 INFO: show_metric:False	-->	Calling Count:0
# 2024-07-04 14:13:55,829 INFO: spacy_model:en_core_web_sm	-->	Calling Count:7
# 2024-07-04 14:13:55,830 INFO: srd_alignment:True	-->	Calling Count:0
# 2024-07-04 14:13:55,831 INFO: task_code:ATEPC	-->	Calling Count:1
# 2024-07-04 14:13:55,833 INFO: task_name:Aspect Term Extraction and Polarity Classification	-->	Calling Count:0
# 2024-07-04 14:13:55,834 INFO: tokenizer:DebertaV2TokenizerFast(name_or_path='microsoft/deberta-v3-base', vocab_size=128000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '[CLS]', 'eos_token': '[SEP]', 'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	3: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=True, special=True),
# 	128000: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }	-->	Calling Count:0
# 2024-07-04 14:13:55,836 INFO: use_amp:False	-->	Calling Count:1
# 2024-07-04 14:13:55,840 INFO: use_bert_spc:True	-->	Calling Count:0
# 2024-07-04 14:13:55,841 INFO: use_syntax_based_SRD:False	-->	Calling Count:4722
# 2024-07-04 14:13:55,842 INFO: verbose:False	-->	Calling Count:1
# 2024-07-04 14:13:55,843 INFO: warmup_step:-1	-->	Calling Count:0
# 2024-07-04 14:13:55,845 INFO: window:lr	-->	Calling Count:0
# [2024-07-04 14:13:56] (2.4.1.post1) ********** Available ATEPC model checkpoints for Version:2.4.1.post1 (this version) **********
# [2024-07-04 14:13:56] (2.4.1.post1) ********** Available ATEPC model checkpoints for Version:2.4.1.post1 (this version) **********
# [2024-07-04 14:13:56] (2.4.1.post1) Downloading checkpoint:english
# [2024-07-04 14:13:56] (2.4.1.post1) Notice: The pretrained model are used for testing, it is recommended to train the model on your own custom datasets
# Downloading checkpoint: 579MB [00:56, 10.16MB/s]
# Find zipped checkpoint: ./checkpoints/ATEPC_ENGLISH_CHECKPOINT/fast_lcf_atepc_English_cdw_apcacc_82.36_apcf1_81.89_atef1_75.43.zip, unzipping
# Done.
# [2024-07-04 14:14:58] (2.4.1.post1) If the auto-downloading failed, please download it via browser: https://huggingface.co/spaces/yangheng/PyABSA/resolve/main/checkpoints/English/ATEPC/fast_lcf_atepc_English_cdw_apcacc_82.36_apcf1_81.89_atef1_75.43.zip
# 2024-07-04 14:14:58,759 INFO: Checkpoint downloaded at: checkpoints/ATEPC_ENGLISH_CHECKPOINT/fast_lcf_atepc_English_cdw_apcacc_82.36_apcf1_81.89_atef1_75.43
# 2024-07-04 14:14:59,138 INFO: Resume trainer from Checkpoint: checkpoints/ATEPC_ENGLISH_CHECKPOINT/fast_lcf_atepc_English_cdw_apcacc_82.36_apcf1_81.89_atef1_75.43!
# 2024-07-04 14:14:59,139 INFO: ***** Running training for Aspect Term Extraction and Polarity Classification *****
# 2024-07-04 14:14:59,140 INFO:   Num examples = 3604
# 2024-07-04 14:14:59,142 INFO:   Batch size = 16
# 2024-07-04 14:14:59,143 INFO:   Num steps = 2250
# Epoch:  0| loss_apc:0.0256 | loss_ate:0.0828 |: 100%|██████████| 226/226 [03:26<00:00,  1.09it/s,  APC_ACC: 88.28(max:88.28) | APC_F1: 82.70(max:82.70) | ATE_F1: 83.74(max:83.79)]
# Epoch:  1| loss_apc:0.0050 | loss_ate:0.0135 |: 100%|██████████| 226/226 [03:19<00:00,  1.13it/s,  APC_ACC: 88.01(max:88.28) | APC_F1: 81.83(max:82.70) | ATE_F1: 85.10(max:85.10)]
# Epoch:  2| loss_apc:0.0008 | loss_ate:0.0074 |: 100%|██████████| 226/226 [03:35<00:00,  1.05it/s,  APC_ACC: 87.30(max:88.28) | APC_F1: 80.56(max:82.70) | ATE_F1: 84.41(max:85.10)]
# 2024-07-04 14:25:42,127 INFO:
# -------------------------------------------------------------------- Raw Metric Records --------------------------------------------------------------------
# ╒════════════════════════════════╤═══════════════════════════════════════════════════════╤══════════╤═══════════╤══════════╤═══════╤═══════╤═══════╤═══════╕
# │ Metric                         │ Trial                                                 │ Values   │  Average  │  Median  │  Std  │  IQR  │  Min  │  Max  │
# ╞════════════════════════════════╪═══════════════════════════════════════════════════════╪══════════╪═══════════╪══════════╪═══════╪═══════╪═══════╪═══════╡
# │ Max-APC-Test-Acc w/o Valid Set │ fast_lcf_atepc-Restaurant14-microsoft/deberta-v3-base │ [88.28]  │   88.28   │  88.28   │   0   │   0   │ 88.28 │ 88.28 │
# ├────────────────────────────────┼───────────────────────────────────────────────────────┼──────────┼───────────┼──────────┼───────┼───────┼───────┼───────┤
# │ Max-APC-Test-F1 w/o Valid Set  │ fast_lcf_atepc-Restaurant14-microsoft/deberta-v3-base │ [82.7]   │   82.7    │   82.7   │   0   │   0   │ 82.7  │ 82.7  │
# ├────────────────────────────────┼───────────────────────────────────────────────────────┼──────────┼───────────┼──────────┼───────┼───────┼───────┼───────┤
# │ Max-ATE-Test-F1 w/o Valid Set  │ fast_lcf_atepc-Restaurant14-microsoft/deberta-v3-base │ [85.1]   │   85.1    │   85.1   │   0   │   0   │ 85.1  │ 85.1  │
# ╘════════════════════════════════╧═══════════════════════════════════════════════════════╧══════════╧═══════════╧══════════╧═══════╧═══════╧═══════╧═══════╛
# ----------------------------------------------------- https://github.com/yangheng95/metric_visualizer -----------------------------------------------------
#
# 2024-07-04 14:25:42,140 INFO: ABSADatasetsVersion:None	-->	Calling Count:0
# 2024-07-04 14:25:42,141 INFO: IOB_label_to_index:{'B-ASP': 1, 'I-ASP': 2, 'O': 3, '[CLS]': 4, '[SEP]': 5}	-->	Calling Count:1
# 2024-07-04 14:25:42,142 INFO: MV:<metric_visualizer.metric_visualizer.MetricVisualizer object at 0x7fa93cd207f0>	-->	Calling Count:4
# 2024-07-04 14:25:42,142 INFO: PyABSAVersion:2.4.1.post1	-->	Calling Count:1
# 2024-07-04 14:25:42,143 INFO: SRD:3	-->	Calling Count:9444
# 2024-07-04 14:25:42,145 INFO: TorchVersion:2.3.1+cu121+cuda12.1	-->	Calling Count:1
# 2024-07-04 14:25:42,146 INFO: TransformersVersion:4.42.3	-->	Calling Count:1
# 2024-07-04 14:25:42,147 INFO: auto_device:True	-->	Calling Count:682
# 2024-07-04 14:25:42,148 INFO: batch_size:16	-->	Calling Count:6
# 2024-07-04 14:25:42,149 INFO: cache_dataset:True	-->	Calling Count:1
# 2024-07-04 14:25:42,150 INFO: checkpoint_save_mode:1	-->	Calling Count:4
# 2024-07-04 14:25:42,151 INFO: cross_validate_fold:-1	-->	Calling Count:2
# 2024-07-04 14:25:42,152 INFO: dataset_file:{'train': ['integrated_datasets/atepc_datasets/110.SemEval/114.restaurant14/Restaurants_Train.xml.seg.atepc'], 'test': ['integrated_datasets/atepc_datasets/110.SemEval/114.restaurant14/Restaurants_Test_Gold.xml.seg.atepc'], 'valid': []}	-->	Calling Count:6
# 2024-07-04 14:25:42,153 INFO: dataset_name:Restaurant14	-->	Calling Count:10
# 2024-07-04 14:25:42,153 INFO: device:cuda:0	-->	Calling Count:10525
# 2024-07-04 14:25:42,154 INFO: device_name:NVIDIA GeForce GTX 1070	-->	Calling Count:1
# 2024-07-04 14:25:42,155 INFO: dropout:0.5	-->	Calling Count:1
# 2024-07-04 14:25:42,157 INFO: dynamic_truncate:True	-->	Calling Count:9444
# 2024-07-04 14:25:42,158 INFO: embed_dim:768	-->	Calling Count:0
# 2024-07-04 14:25:42,158 INFO: evaluate_begin:0	-->	Calling Count:7
# 2024-07-04 14:25:42,159 INFO: from_checkpoint:english	-->	Calling Count:4
# 2024-07-04 14:25:42,159 INFO: gradient_accumulation_steps:1	-->	Calling Count:3
# 2024-07-04 14:25:42,160 INFO: hidden_dim:768	-->	Calling Count:6
# 2024-07-04 14:25:42,160 INFO: index_to_IOB_label:{1: 'B-ASP', 2: 'I-ASP', 3: 'O', 4: '[CLS]', 5: '[SEP]'}	-->	Calling Count:0
# 2024-07-04 14:25:42,161 INFO: index_to_label:{0: 'Negative', 1: 'Neutral', 2: 'Positive'}	-->	Calling Count:2
# 2024-07-04 14:25:42,162 INFO: inference_model:None	-->	Calling Count:0
# 2024-07-04 14:25:42,163 INFO: initializer:xavier_uniform_	-->	Calling Count:0
# 2024-07-04 14:25:42,163 INFO: l2reg:1e-05	-->	Calling Count:2
# 2024-07-04 14:25:42,164 INFO: label_list:['B-ASP', 'I-ASP', 'O', '[CLS]', '[SEP]']	-->	Calling Count:8
# 2024-07-04 14:25:42,165 INFO: label_to_index:{'Negative': 0, 'Neutral': 1, 'Positive': 2}	-->	Calling Count:0
# 2024-07-04 14:25:42,166 INFO: lcf:cdw	-->	Calling Count:2339
# 2024-07-04 14:25:42,166 INFO: learning_rate:2e-05	-->	Calling Count:1
# 2024-07-04 14:25:42,167 INFO: load_aug:False	-->	Calling Count:1
# 2024-07-04 14:25:42,167 INFO: log_step:226	-->	Calling Count:680
# 2024-07-04 14:25:42,168 INFO: logger:<Logger fast_lcf_atepc (INFO)>	-->	Calling Count:17
# 2024-07-04 14:25:42,168 INFO: loss:0.08525061514228582	-->	Calling Count:0
# 2024-07-04 14:25:42,169 INFO: max_seq_len:80	-->	Calling Count:35392
# 2024-07-04 14:25:42,170 INFO: max_test_metrics:{'max_apc_test_acc': 88.28, 'max_apc_test_f1': 82.7, 'max_ate_test_f1': 85.1}	-->	Calling Count:50
# 2024-07-04 14:25:42,170 INFO: metrics_of_this_checkpoint:{'apc_acc': 87.3, 'apc_f1': 80.56, 'ate_f1': 84.41}	-->	Calling Count:18
# 2024-07-04 14:25:42,171 INFO: model:<class 'pyabsa.tasks.AspectTermExtraction.models.__lcf__.fast_lcf_atepc.FAST_LCF_ATEPC'>	-->	Calling Count:5
# 2024-07-04 14:25:42,172 INFO: model_name:fast_lcf_atepc	-->	Calling Count:4743
# 2024-07-04 14:25:42,172 INFO: model_path_to_save:checkpoints	-->	Calling Count:10
# 2024-07-04 14:25:42,173 INFO: notice:This is an training example for aspect term extraction	-->	Calling Count:0
# 2024-07-04 14:25:42,173 INFO: num_epoch:10	-->	Calling Count:2
# 2024-07-04 14:25:42,174 INFO: num_labels:6	-->	Calling Count:2
# 2024-07-04 14:25:42,174 INFO: optimizer:adamw	-->	Calling Count:2
# 2024-07-04 14:25:42,175 INFO: output_dim:3	-->	Calling Count:8
# 2024-07-04 14:25:42,176 INFO: overwrite_cache:False	-->	Calling Count:0
# 2024-07-04 14:25:42,178 INFO: path_to_save:None	-->	Calling Count:1
# 2024-07-04 14:25:42,179 INFO: patience:2	-->	Calling Count:4
# 2024-07-04 14:25:42,179 INFO: pretrained_bert:microsoft/deberta-v3-base	-->	Calling Count:8
# 2024-07-04 14:25:42,180 INFO: save_mode:1	-->	Calling Count:6
# 2024-07-04 14:25:42,182 INFO: seed:1	-->	Calling Count:6
# 2024-07-04 14:25:42,182 INFO: sep_indices:2	-->	Calling Count:26464
# 2024-07-04 14:25:42,183 INFO: show_metric:False	-->	Calling Count:0
# 2024-07-04 14:25:42,184 INFO: spacy_model:en_core_web_sm	-->	Calling Count:7
# 2024-07-04 14:25:42,185 INFO: srd_alignment:True	-->	Calling Count:0
# 2024-07-04 14:25:42,186 INFO: task_code:ATEPC	-->	Calling Count:2
# 2024-07-04 14:25:42,189 INFO: task_name:Aspect Term Extraction and Polarity Classification	-->	Calling Count:1
# 2024-07-04 14:25:42,190 INFO: tokenizer:DebertaV2TokenizerFast(name_or_path='microsoft/deberta-v3-base', vocab_size=128000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '[CLS]', 'eos_token': '[SEP]', 'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	3: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=True, special=True),
# 	128000: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }	-->	Calling Count:0
# 2024-07-04 14:25:42,191 INFO: use_amp:False	-->	Calling Count:1357
# 2024-07-04 14:25:42,192 INFO: use_bert_spc:True	-->	Calling Count:1658
# 2024-07-04 14:25:42,194 INFO: use_syntax_based_SRD:False	-->	Calling Count:4722
# 2024-07-04 14:25:42,194 INFO: verbose:False	-->	Calling Count:1
# 2024-07-04 14:25:42,195 INFO: warmup_step:-1	-->	Calling Count:680
# 2024-07-04 14:25:42,196 INFO: window:lr	-->	Calling Count:0

# %%
aspect_extractor = trainer.load_trained_model()
assert isinstance(aspect_extractor, ATEPC.AspectExtractor)
# Out:
# [2024-07-04 14:28:38] (2.4.1.post1) Load aspect extractor from checkpoints/fast_lcf_atepc_Restaurant14_cdw_apcacc_88.01_apcf1_81.83_atef1_85.1/
# [2024-07-04 14:28:38] (2.4.1.post1) config: checkpoints/fast_lcf_atepc_Restaurant14_cdw_apcacc_88.01_apcf1_81.83_atef1_85.1/fast_lcf_atepc.config
# [2024-07-04 14:28:38] (2.4.1.post1) state_dict: checkpoints/fast_lcf_atepc_Restaurant14_cdw_apcacc_88.01_apcf1_81.83_atef1_85.1/fast_lcf_atepc.state_dict
# [2024-07-04 14:28:38] (2.4.1.post1) model: None
# [2024-07-04 14:28:38] (2.4.1.post1) tokenizer: checkpoints/fast_lcf_atepc_Restaurant14_cdw_apcacc_88.01_apcf1_81.83_atef1_85.1/fast_lcf_atepc.tokenizer
# [2024-07-04 14:28:38] (2.4.1.post1) Set Model Device: cuda:0
# [2024-07-04 14:28:38] (2.4.1.post1) Device Name: NVIDIA GeForce GTX 1070

# %%
for comment in df_comments_only_eng_short['value'][:1]:
    aspect_extractor.predict(comment)
# Out:
# [2024-07-04 14:30:27] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:27] (2.4.1.post1) Example 0: Great <game:Positive Confidence:0.9985> , full controllo of your <strategy:Positive Confidence:0.999> through constant adjustment of your tactic watching what your opponents do .
# [2024-07-04 14:30:28] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:28] (2.4.1.post1) Example 0: Very clever game , enjoyable overall . Plus points : Great production values for all components and very good value for money . Lovely artwork everywhere . Smooth game play mechanisms - ironed out some oddities of the original game . Fortunes change frequently , so the winner could be anyone . Minus points : The board and card artwork is generally too dark ( even on the light side of the board ) , making it hard for some people to see detail clearly , especially under artificial lights in the evening . The rules are all in the rule book . Not necessarily where you ' d expect to find them though . The addition of beer , manufactured goods and pottery is a double edged sword : Nice to have variety but makes things harder to grasp for new players and even experienced players . We found the need for beer to get most things done annoying . Needing coal and iron was already obstacle enough . Lots of fiddly network / connection rules that everyone forgot at some point , necessitating a lot of reversing what you ' ve just done in order to replace it with something legal . AP really set in over the last half a dozen turns as we scrutinized the whole board and our last remaining cards to try to spot final scoring opportunities . Everyone was affected , so the game slowed down a lot , sucking the fun out of it with so much downtime . The last couple of turns had so much AP delay that I went away to fold laundry for a while . Overall I ' d play it again but I prefer Brass Lancashire .
# [2024-07-04 14:30:29] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:29] (2.4.1.post1) Example 0: Brilliant ! Fits right into my wheelhouse all around and game <weight:Positive Confidence:0.9995> . This also has some of the most and best player <interaction:Positive Confidence:0.9995> I ' ve experienced in a game !
# [2024-07-04 14:30:30] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:30] (2.4.1.post1) Example 0: Absolutely brilliant ! I never played the original Brass , and now I don ' t need to . The <art:Positive Confidence:0.999> , <mechanics:Positive Confidence:0.9988> , and <pacing:Positive Confidence:0.9986> of the <game:Positive Confidence:0.9986> is excellent . I absolutely love the the " tale of two halves " type of mechanic that rewards preparation . I have limited experience with Euro ' s , but this game has become my personal Euro litmus test .
# [2024-07-04 14:30:31] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:31] (2.4.1.post1) Example 0: I prefer old school <Brass:Positive Confidence:0.9699> or AoI . I do like that the dumb foreign market is gone in this version but the addition of <beer:Neutral Confidence:0.853> seems like a contrivance
# [2024-07-04 14:30:32] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:32] (2.4.1.post1) Example 0: The game itself is not interesting enough to learn it ' s metagame . Also , it ' s terrible at demonstrating the possible value of different strategies , other than the general " rail building " path . Sadly that ' s one of the best point source in a 4 player game . Lack of game balance and play - testing is an issue . The game is mechanically solid , ( It has some beautiful interactions ! ) But this game itself is under developed . Exploring a game by playing it is fun , but it ' s usually about learning how to do a strategy , and not finding out , how well a strategy preforms .
# [2024-07-04 14:30:32] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:32] (2.4.1.post1) Example 0: This is a near - perfect board <game:Positive Confidence:0.9994> because . . . The <rules:Positive Confidence:0.9994> are relatively simple and easy for new players to learn . Significant player - to - player interaction during the game . The ability to learn the historical background . The <artwork:Positive Confidence:0.9994> and accessories are beautiful .
# [2024-07-04 14:30:33] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:33] (2.4.1.post1) Example 0: Excellent and highly interactive game . Probably the best realisation of market supply and demand in a board game . Every action another player takes has a major influence on your strategy and the decisions you will make , from deficiencies in the resource market waiting to be filled up , new trade networks being established , or precious beer becoming available to guzzle down . Opportunities are primarily player driven and you have to keep your strategy flexible enough to take advantage of what others are doing . Everything about the design is so well crafted and gives your decision making so many more layers . The hand management , turn order manipulation based on your spending , the appropriately thematic change from canal era to rail era , these elements all work together to make Brass greater than the sum of its parts . The rules are complex and it can take a play or two to internalise the systems , and the Roxley production is very pretty , but sacrifices usability with the overly dark board and hard to see canal / rail links . But these are minor nitpicks that will not stop me from playing this masterpiece .
# [2024-07-04 14:30:34] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:34] (2.4.1.post1) Example 0: Great <game:Positive Confidence:0.9966> , great <material:Positive Confidence:0.9893> ( think delux maybe not raquired , only chips are changed ) und lots of " Langzeitspielspass " . 7 because story elements are missing .
# [2024-07-04 14:30:35] (2.4.1.post1) Can not load en_core_web_sm from spacy, try to download it in order to parse syntax tree:
# python -m spacy download en_core_web_sm
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: setuptools in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (59.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.4)
# Requirement already satisfied: jinja2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: packaging>=20.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.0)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: numpy>=1.19.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.10.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [2024-07-04 14:30:43] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:43] (2.4.1.post1) Example 0: While it might be a heretical opinion to some , I think this is the objectively superior <Brass:Positive Confidence:0.9953> . The removal of the cotton market and the smoothing out of <randomness:Positive Confidence:0.9067> thanks to the improved wildcards really makes it more of a game of skill and less of a game of luck in the end . Takes a great game and makes it even better .
# [2024-07-04 14:30:44] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:44] (2.4.1.post1) Example 0: The absolute best <game:Positive Confidence:0.9977> I ' ve ever played . Not sure what exactly makes it better , but it ' s the game o crave the most .
# [2024-07-04 14:30:45] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:45] (2.4.1.post1) Example 0: After walking away from it several times due to its <graphics:Negative Confidence:0.7838> , finally tried to play it . Very difficult , slow and confusing due to <graphics:Negative Confidence:0.7838> . Good game whose graphics make it mostly unplayable . Dark ugly <theme:Negative Confidence:0.9956> even on the " day side " . Tiny <text:Negative Confidence:0.9959> and symbology not good for 20 - 20 aging eyes .
# [2024-07-04 14:30:46] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:46] (2.4.1.post1) Example 0: My 2018 <Game:Neutral Confidence:0.6204> of the Year .
# [2024-07-04 14:30:47] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:47] (2.4.1.post1) Example 0: I have <Brass:Neutral Confidence:0.7081> . I have Brass : Lancashire . I need Brass : Birmingham
# [2024-07-04 14:30:47] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:47] (2.4.1.post1) Example 0: Love it but hate my friends ap . . .
# [2024-07-04 14:30:48] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:48] (2.4.1.post1) Example 0: An incredible <game:Positive Confidence:0.9974> quite unlike any other game I ' ve played before . It is a bear to teach or learn but well worth it especially for people who can bring it out frequently .
# [2024-07-04 14:30:49] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:49] (2.4.1.post1) Example 0: Very well designed <game:Positive Confidence:0.9992> , always a tight race and super competitive on the board .
# [2024-07-04 14:30:50] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:50] (2.4.1.post1) Example 0: enjoyed it straight away , not too hard to learn the <rules:Positive Confidence:0.9088> , good strategy needed , preferred Lancashire , less complex than this , so just kept the other
# [2024-07-04 14:30:51] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:51] (2.4.1.post1) Example 0: Excellent <game:Positive Confidence:0.8695> but a little more AP prone than Lancashire and also plays longer ( esp . with 4 players ) . The addition of <beer:Neutral Confidence:0.9755> and new industries as well as one time bonuses instead of distant market tiles is a nice variation .
# [2024-07-04 14:30:52] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:52] (2.4.1.post1) Example 0: 4 plays / 3 , 4 players LIKE : It ' s Brass , with more nuances . The beer slows down the trading path , by adding a layer . The trading ports themselves are great , it creates a fresh , varied state for the map positioning with each new play , a great addition . I think that option alone may make this better than the original . The pottery is somewhat equivalent to the shipyards . DISLIKE : More nuances , so it increases the play time slightly , more analysis paralysis . Still fiddly as ever . Many corner case rules , so many that I find it difficult to remember them all unless another player is familiar with the rules as well . OVERALL : Love it . Our first game took about 4 hours . It seems there could be more strategies with this version . I am now interested in Age of Industry to see if there is a way to get the playtime down .
# [2024-07-04 14:30:53] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:53] (2.4.1.post1) Example 0: After two plays of Lancashire and now one of Birmingham , I ' m not too sure what to make of these games . They are deep , thinky and very interactive . On the other hand , they are very AP inducing ( perhaps more than any other game I ' ve played ) , the rules are ' quirky ' and the card play feels odd to me . This feels more like a variant than a standalone game . I think the changes are an improvement and this is the better version .
# [2024-07-04 14:30:54] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:54] (2.4.1.post1) Example 0: There is something pretty special about Brass : Birmingham . Though the rules are pretty complex and fiddly at the beginning ( especially networks and the way coal is different from everything else ) , but this leads to an immense depth of play . The cards are a wonderful constraint and will drive you to rage . At higher player counts , the opportunities to disrupt each other in horrifying ways become more and more frequent . It also actually feels like a simulation , instead of an exercise in number crunching . The beer element might feel a bit tacked on , but it is easily explained away and is necessary to add that final " oomf " to the strategy . One of the deepest and cleanest economic simulations I ' ve played , though it might not look very clean the first time you play . Highly recommended for some crunchy industrialization action !
# [2024-07-04 14:30:55] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:55] (2.4.1.post1) Example 0: GameGenic matte sleeves ; 3D printed insert
# [2024-07-04 14:30:56] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:56] (2.4.1.post1) Example 0: Rulebook is not great . I do like it better than <Gloomhaven:Negative Confidence:0.9987> , but in my opinion it is boring and I ' m surprised it moved to the top spot .
# [2024-07-04 14:30:56] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:56] (2.4.1.post1) Example 0: Economic Heavy Strategy ( 4 ) Build , <Network:Neutral Confidence:0.9779> , Develop , Sell , Take Loans & Scout As You build Your Industrial Empire In The TOP Rated Game On BGG [ @ C & CBrum ]
# [2024-07-04 14:30:57] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:57] (2.4.1.post1) Example 0: I personally like Lancashire better , but may it is very good . I might grow to like it with more plays .
# [2024-07-04 14:30:58] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:58] (2.4.1.post1) Example 0: A brilliantly executed fiscal puzzle .
# [2024-07-04 14:30:59] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:30:59] (2.4.1.post1) Example 0: This is more or less the same game as the original Brass except for the increased number and the new type of industries and the additional resource ( beer ) . The basic mechanics are the same still . However since there are more types of industry , players have more options for specialising . In other words , this translates to an increased number of fundamental basic strategies than in the original . The downside is that the competition can be less cutthroat and there are more rules to explain . Another change in the game is that links no longer score on the basis of the number of industry it connects . Instead the industries have a specific link value ( 0 - 2 VP ) thus complicating the things a bit . I really cannot decide between this and the original . This may offer more variation from game to game but rules are more elegant in the original ( although badly written which just happens to be Wallace ’ s trademark ) .
# [2024-07-04 14:31:00] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:00] (2.4.1.post1) Example 0: See my review here ( spoiler alert : it is great , and <works:Positive Confidence:0.9993> excellent with 2 players ) - https : / / boardgamegeek . com / thread / 2738568 / game - lunar - society - birmingham - would - play - boardgame
# [2024-07-04 14:31:01] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:01] (2.4.1.post1) Example 0: Oh man , having to choose between this and Lancashire is so difficult ! One of our best times playing Brass was with Birmingham , and <beer:Positive Confidence:0.9971> is so versatile and fun , but I also quite like the simpler <rules:Positive Confidence:0.9316> in Lancashire . . . both are great titles either way .
# [2024-07-04 14:31:02] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:02] (2.4.1.post1) Example 0: December 2022 - 10 - 8 + plays + Excellent game , always so much fun . + Great decisions with the cards managing which ones to use to build vs other actions where the card type does not matter . + Fun market for iron / coal and using other players resources . + Simple rules but lots of complexity arises during gameplay . + Crucial to be aware of what opponents are doing . - First time can be a bit confusing what is part of your " network " and when you can use coal from the market .
# [2024-07-04 14:31:03] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:03] (2.4.1.post1) Example 0: Simply one of the best , a true Euro masterpiece . Too bad they couldn ' t include a different map on the other side at least , like Power Grid has . Also would be nice to have some better quality <components:Negative Confidence:0.9983> , like for canals and trains .
# [2024-07-04 14:31:03] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:03] (2.4.1.post1) Example 0: This <game:Positive Confidence:0.9991> is perfectly balanced , it builds up intense ambience through the end game . The pick up and delivery mechanic is quite interesting too , the <rules:Positive Confidence:0.9993> makes sense , and the deluxe edition clay chip is marvellous .
# [2024-07-04 14:31:05] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:05] (2.4.1.post1) Example 0: I can see why this game is so popular , even though I disagree with its # 1 ranking on BGG . I stayed away from this game for a long time because the theme doesn ' t appeal to me and because I ' m in general not a fan of most Euros . While the theme feels very much painted on , this game is a hybrid and not a pure Euro - style game . The game is as much about player conflict ( via area control ) as much as it is about building an economic engine . The game also encourages table - talk and presents opportunities for deal - making . But the thing that stands out the most is how intricate and yet tight / crisp the puzzle is . Like Ark Nova ( my favorite Euro ) , this game requires you to play your hand instead of waiting for cards to fit your strategy , and I love that . There is also so much scope for deep strategy in this game . The game is not without its flaws though . First , the game is not thematic at all - and that ' s always a big negative for me personally . Second , the game does not have a catch - up mechanism . Once someone is ahead , it ' s very likely they ' ll win . Also , a couple of bad early moves pretty much kill your game . I also found the whole beer / different industries mechanic to be kind of unnecessary . I ' ve watched online plays of Brass : Lancashire which doesn ' t have this mechanic , and I think that might be a better fit , at least for people starting out with the Brass system . Brass : Birmingham almost feels like an expansion to Brass : Lancashire that should not be played as your first game . All in all , I ' d like to play this game more and can see my rating going up . ( Plays : 1 )
# [2024-07-04 14:31:06] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:06] (2.4.1.post1) Example 0: Sleeved with Arcane Tinmen - <Standard:Neutral Confidence:0.9985> - 76 cards
# [2024-07-04 14:31:07] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:07] (2.4.1.post1) Example 0: I cannot say whether or not it is better than Brass Lancashire , but I would say that it as least as good . I did enjoy the <beer:Positive Confidence:0.9994> , the <potteries:Positive Confidence:0.9994> and the market mechanism . Excellent game , and not too long either .
# [2024-07-04 14:31:07] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:07] (2.4.1.post1) Example 0: Brilliant game that deserves all the hype it ' s getting . I enjoyed every play and was surprised by how well some casuals responded to it . I did feel making foam core inserts was essential as setup can be a drag otherwise . Not for everybody as the dark tone and <theme:Negative Confidence:0.9989> can turn some people off . Played 2p , 3p and 4p .
# [2024-07-04 14:31:08] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:08] (2.4.1.post1) Example 0: A great <game:Positive Confidence:0.9903> , although sadly not one I like playing often as I tend to feel I end with a headache . . .
# [2024-07-04 14:31:09] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:09] (2.4.1.post1) Example 0: Very similar to Brass Lancashire , it ' s an awesome economic game mainly for experienced players . It ' s difficult to explain all the <rules:Positive Confidence:0.6819> . The <components:Positive Confidence:0.9383> are amazing
# [2024-07-04 14:31:10] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:10] (2.4.1.post1) Example 0: my second favorite <game:Positive Confidence:0.9995> . . .
# [2024-07-04 14:31:11] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:11] (2.4.1.post1) Example 0: My top 1 economic <games:Positive Confidence:0.9995> . A must played in every single game session . Good with two players
# [2024-07-04 14:31:12] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:12] (2.4.1.post1) Example 0: Production : 10 / 10 <Rules Teach:Positive Confidence:0.9991> : 7 / 10 <Replay Value:Positive Confidence:0.9992> : 10 / 10 <Scalability:Positive Confidence:0.9993> : 9 / 10 <Fun:Positive Confidence:0.9992> Factor : 10 / 10
# [2024-07-04 14:31:13] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:13] (2.4.1.post1) Example 0: In my opinion , Lancashire is much better . Lancashire is more straightforward and you focus on the strategy . You don ' t get tired of the multitude of tokens , in Lancashire there is only the essential ones . After playing Birmingham I always felt exhausted , but still liked the <game:Positive Confidence:0.9353> . However , after playing Lancashire the time just flew and I would have wanted to play again right away .
# [2024-07-04 14:31:14] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:14] (2.4.1.post1) Example 0: Fantastic <strategic depth:Positive Confidence:0.9989> , plays very differently based on the number of players . A game where you need to be aware of the current setting at all times to make the best move . Not great for people that want to move fast , but for those that like to really make the most of thinking several moves ahead , a fantastic game .
# [2024-07-04 14:31:15] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:15] (2.4.1.post1) Example 0: Birmingham is more of a variant to the original Brass . More tactical game than the original .
# [2024-07-04 14:31:16] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:16] (2.4.1.post1) Example 0: Solid <game:Positive Confidence:0.9989> , lot of setup .
# [2024-07-04 14:31:16] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:16] (2.4.1.post1) Example 0: Wonderful game ! It ' s really not as tough to teach as the weight it ' s given . Make sure to watch the how to play video by ' watch it played ' on youtube . I also recommend the player aids in the files section of BGG . With both of those things done first , it took my play group about 20 minutes to get going . Some of the rules are a bit arbitrary and hard to remember , but after one play through you should have the hang of it . It ' s an intriguing game of give and takes . It ' s mostly resource management and strategic placement to set yourself up for big future turns . It also requires quick thinking on your feet because it ' s very easy to get your plan squashed by your opponents progress . Every system in the game is well designed and thought out . You ' ll be surprised as you play at how connected everything is . I soon realized that it ' s impossible to focus on everything . You ' ll have to utilize your opponent ' s resources and infrastructure to advance your goals . Many games remove all ' take - that ' mechanics where your actions can negatively impact other players . Brass : Birmingham takes a refreshing look at meddling with your opponents : they can gain victory points and upgrades when you steal their stuff , so you will have to weigh every decision . I found that I also took all of the types of actions all throughout the game . There was never a bland moment , especially with the two phases of the game keeping it fresh . Overall , probably the best strategy board game I have ever played !
# [2024-07-04 14:31:17] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:17] (2.4.1.post1) Example 0: I expected this to be a once - in - a - blue - moon game that ' s fun for hardcore boardgamers , but the simplicity of the <engine:Positive Confidence:0.9986> mixed with the feeling of steady progress as your strategies get better and better with each play makes it a banger game that ' s a permanent addition to my collection .
# [2024-07-04 14:31:18] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:18] (2.4.1.post1) Example 0: Historic hand management economic engine
# [2024-07-04 14:31:19] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:19] (2.4.1.post1) Example 0: Wonderful <game:Positive Confidence:0.9967> . I like design and mechanism .
# [2024-07-04 14:31:20] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:20] (2.4.1.post1) Example 0: I quite like this , I have to say , the balance between helping yourself and helping your competitors is tight , and there are lots of tactical as well as <strategic:Positive Confidence:0.9935> options .
# [2024-07-04 14:31:21] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:21] (2.4.1.post1) Example 0: [ b ] Extras : [ / b ] [ thing = 306354 ] [ / thing ]
# [2024-07-04 14:31:22] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:22] (2.4.1.post1) Example 0: I can see why people like this as the puzzle is there , but there are just too many rules exceptions and fiddles ( and tiny <icons:Negative Confidence:0.9986> changing tile to tile ) . This just interrupts the flow and makes errors inevitable .
# [2024-07-04 14:31:23] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:23] (2.4.1.post1) Example 0: " Meeple Realty Insert ( Stained ) "
# [2024-07-04 14:31:24] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:24] (2.4.1.post1) Example 0: Base game Kickstarter Jan 2018 Brass full bundle pledge - Brass Lancashire deluxe - Brass Birmingham deluxe
# [2024-07-04 14:31:24] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:24] (2.4.1.post1) Example 0: This is one of the few games in the bgg top 10 that definitely deserves it . There is something about this game that is really hard to put into words on why it is so great . It is one of those games that you can ' t wait until your turn to execute some clever maneuvers that are pretty rewarding when pulled off . Partially because they reward you with income for the rest of the game and also it establishes some resources that everyone can use . There is so much cleverness built into every aspect of the game in the card system of discarding the same cards you use to build , into the cards being able to built at locations or specific types of buildings . The buildings themselves as sort of a tech tree of of different resource costs , money costs , end game points , and income . There are several different strategies to pursue and some of that will change from game to game because of the market tiles but really the variability comes from the cards themselves as you can only do what they tell you . The card distribution is interesting because some cards are more important than others and ones you might want to hang onto . The scoring is great because it rewards you for building rails as well as buildings so you really want to excel with both . The flow of the game is perfect as the first round you are really working hard to get something going , laying down rails , getting some buildings out , then all the sudden all the level 1 buildings go away but your network is still in place and you can really ramp up in the second era . It can be very difficult to get started because you often might find you need to take a loan which feels counter to most games you play where that is a bad thing . The artwork and components are top notch , nice linen finish on everything with a small box that really packs everything in . A few complaints would be no player aid which is really unfortunate for some a nice production and you have to rely on the community to understand the different actions . Towards the end of the game you get it but the player aid that comes with it is just a few works and the community just showed me what could have been . I imagine the iron clays are incredible if you get those but the standard cardboard money is just fine . I also dislike that we do have to put the money on the turn order track because it can be a little fiddly to stack , you often can ' t reach that side of the board , and keeping it near the players can be problematic remembering which pile is what . I wish there was some way to emulate that mechanism while putting that money back in the bank with some sort of numbered tile , or a cube on a numbered track , or something else . The day / night board is an interesting choice it is interesting that it is there I guess for visibility but I wish it was better utilized as some form of extra content in the game . . . but it probably doesn ' t need it . There is definitely some setup time sorting and fiddlying with those player tokens which can probably only be solved with a plano or tons of little baggies . The player turn times can also be long as some actions cause a big chain reaction while already giving you a lot to think about . Coupled with the fact that turn order is determined by who spent the least means some players can take 4 actions in a row and take quite a long time . I imagine at higher player counts it is definitely more interaction because of the shared world but man those turns could take forever to come around . For us it is perfect at two because we can take awhile and enjoy the game and discuss as we are going . It is hard to write about games you enjoy because ranting comes so easy , but it is just a fine tuned engine of a game . Everything that exists is there to push you without fluff .
# [2024-07-04 14:31:25] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:25] (2.4.1.post1) Example 0: The best <game:Positive Confidence:0.9995> that excists , no doubt .
# [2024-07-04 14:31:26] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:26] (2.4.1.post1) Example 0: Well <designed:Positive Confidence:0.9991> and playable euro <game:Positive Confidence:0.9989> , but nothing more . From games of a similar kind , I would recommend much more Trismegistus , Marco Polo , Tzolkin , Teotihuacan , Great Western Trail , or even West Kingdom trilogy - more exciting , funny and climatic than Brass .
# [2024-07-04 14:31:27] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:27] (2.4.1.post1) Example 0: 2019 . 12 # BoardGames Owned . Purchased for November 2019 FirstThursday .
# [2024-07-04 14:31:28] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:28] (2.4.1.post1) Example 0: THE HOLY GRAIL OF EUROS .
# [2024-07-04 14:31:29] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:29] (2.4.1.post1) Example 0: Not as tight , not as tense as original <Brass:Positive Confidence:0.987> .
# [2024-07-04 14:31:30] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:31:30] (2.4.1.post1) Example 0: An incredibly fun and brain busting game ! I have only played it at two players and it was a good time but I think it plays a bit better at 3 + players . I do have a couple cons to share though . I found myself falling into analysis paralysis A LOT during turns . There ' s so much to do in this game and often times it ' s not very clear what ' s the way to victory . Also , this is not a game for everyone . This is a hard game both to learn and to teach since there are so many nuances to the networks and resources . This is not a game I can always get to the table . Also , set up took a pretty long time , all those pieces on the player boards take a while to set up , though I think that could be eased with inserts , though that ' s an extra purchase . Still , it ' s an incredibly satisfying game when things go your way . Selling multiple businesses in a single turn and getting that huge payout of income feels great . But I can see how this can be very intimidating in some groups . Proceed with caution but if it feels like it ' s up your alley , grab it !
# [2024-07-04 14:31:30] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# ...
# [2024-07-04 14:33:55] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:33:55] (2.4.1.post1) Example 0: Takes a bit to set up - and can have some real brain drain at times - but a deceptively quick and " simple " <game:Positive Confidence:0.8395> for what it is . More approachable than it seems
# [2024-07-04 14:33:56] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:33:56] (2.4.1.post1) Example 0: Perfectly balanced , great fun ; not too long and strategically very tight . Explains geographic theories as you play . Players directly influencing each others plans by their actions . Component - wise on another level in comparison to the usual eurogame . Phenomenal .
# [2024-07-04 14:33:56] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:33:56] (2.4.1.post1) Example 0: heavy <euro:Positive Confidence:0.9965> , interesting game play had fun
# [2024-07-04 14:33:57] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:33:57] (2.4.1.post1) Example 0: boring <theme:Negative Confidence:0.9989> . Unfortunate combination of heavy <strategy:Negative Confidence:0.9964> with unfair options .
# [2024-07-04 14:33:58] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:33:58] (2.4.1.post1) Example 0: Simply one of the best <games:Positive Confidence:0.9995> out there . Also has a great unofficial solomode with Eliza .
# [2024-07-04 14:33:59] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:33:59] (2.4.1.post1) Example 0: Long , and tighter than you ' d think . You won ' t get as much done as you think .
# [2024-07-04 14:34:00] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:34:00] (2.4.1.post1) Example 0: Bought 2nd hand KS version
# [2024-07-04 14:34:01] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:34:01] (2.4.1.post1) Example 0: Rating after only 1 play . It takes more than 1 play for me to get into a game , so it might be unfair to rate it after just 1 play . Rating might change . It is definaltely a solid game ! No doubt well designed . But for some reason it did not engage me compleately . Maybe it would after more plays . If you like smart , leveled , well designed games , then this is very good .
# [2024-07-04 14:34:02] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:34:02] (2.4.1.post1) Example 0: Not really know why this is number 1 boardgame , but it isn ' t a bad game though
# [2024-07-04 14:34:02] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:34:02] (2.4.1.post1) Example 0: A great <game:Positive Confidence:0.9202> in this category . Beautiful <boards:Positive Confidence:0.9814> and <pieces:Positive Confidence:0.9913> with great room for strategy . Only played it twice thus far with 2 people , but looking forward to having a larger party game . I would say that economy games like this aren ' t my favorite board game genre , but this one is well polished and fun . 9 . 5 / 10
# [2024-07-04 14:34:03] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:34:03] (2.4.1.post1) Example 0: very enjoy the <interaction:Positive Confidence:0.9995> between player and the <mechanic:Positive Confidence:0.9993> of the game .
# [2024-07-04 14:34:04] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:34:04] (2.4.1.post1) Example 0: Want to play with > 2 players !
# [2024-07-04 14:34:05] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:34:05] (2.4.1.post1) Example 0: Super boring and dry . Good for the Concordia fans .
# [2024-07-04 14:34:06] (2.4.1.post1) Can not load en_core_web_sm from spacy, try to download it in order to parse syntax tree:
# python -m spacy download en_core_web_sm
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: numpy>=1.19.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: setuptools in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (59.6.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.4)
# Requirement already satisfied: jinja2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: packaging>=20.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.10.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fra/.venv/nlp/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [2024-07-04 14:34:12] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:34:12] (2.4.1.post1) Example 0: Too dry , even compared to other HEAVY <euros:Negative Confidence:0.9987> . If balance and depth is that important , why not to play GO - chess ?
# [2024-07-04 14:34:13] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:34:13] (2.4.1.post1) Example 0: Fully sleeved with Sleeve Kings
# [2024-07-04 14:34:14] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:34:14] (2.4.1.post1) Example 0: First game ( 2p ) was promising , even though I shy away from computing all the implications of the costs / profits in the tech tree . Second and third games left me underwhelmed . Even the the shared incentives and interactions are great , it all comes down to finding efficient builds , adapting them to the situation and minmaxing efficiency . A bit too pointsaladly for me
# [2024-07-04 14:34:14] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:34:14] (2.4.1.post1) Example 0: Unfortunately quite underwhelming given its reputation . While strategically very complex , it lacks any dramatic or social aspects present in most other network building games . It also lacks significant dips and surges in particular markets , making it nigh impossible to weigh the benefits of different actions . Still , the systems are very clean and flow well among small groups , and I appreciate the dedication to the historical theme . 4 / 10 .
# [2024-07-04 14:34:15] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:34:15] (2.4.1.post1) Example 0: Inferior to Lancashire . Still good though , still <Brass:Negative Confidence:0.9975> .
# [2024-07-04 14:34:16] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:34:16] (2.4.1.post1) Example 0: PnP , 1 - 4 <players:Neutral Confidence:0.9982> , 120 - 180 min
# [2024-07-04 14:34:17] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:34:17] (2.4.1.post1) Example 0: Uhhh , I hope I won ' t play this ever again . I prefer games over brain excersises . From the similar type of games , I ' d play Le Haver over this any time .
# [2024-07-04 14:34:18] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:34:18] (2.4.1.post1) Example 0: Brass : Friendlier version . Randomisation and more open markets make this a great way to <teach:Positive Confidence:0.9994> the game , and a more casual game with the same great mechanisms . I prefer the teeth that are present in Lancashire though .
# [2024-07-04 14:34:19] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:34:19] (2.4.1.post1) Example 0: The same solid economic elements which make the predecessor edition a benchmark treatment of investing as a board game , here cleaned up , dressed up and relaxed to allow greater breathing space . Somewhat unnecessarily overelaborate . Can easily run > 3 hours
# [2024-07-04 14:34:19] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2024-07-04 14:34:19] (2.4.1.post1) Example 0: Kickstarter , rec ' d 8 / 10 Steam Application AI : Easy , Med - Lost ( 3rd ) Easy , Easy - Won , 142pts Easy , Easy - Won , 126pts Easy , Med - Lost ( 3rd ) , 129pts Easy , Med - Won , 138pts Med , Med - Won , 142pts Med , Med - 2nd Med , Med - 2nd - 138pts to 142pts Med , Med - 2nd - 128pts to 138pts

# %%
ckpts = (
    available_checkpoints(TaskCodeOption.Aspect_Term_Extraction_and_Classification)
)  
aspect_extractor = ATEPC.AspectExtractor(
    checkpoint="english"
)
# Out:
# [2024-07-10 15:37:31] (2.4.1.post1) ********** Available ATEPC model checkpoints for Version:2.4.1.post1 (this version) **********
# [2024-07-10 15:37:31] (2.4.1.post1) ********** Available ATEPC model checkpoints for Version:2.4.1.post1 (this version) **********
# [2024-07-10 15:37:31] (2.4.1.post1) ********** Available ATEPC model checkpoints for Version:2.4.1.post1 (this version) **********
# [2024-07-10 15:37:31] (2.4.1.post1) ********** Available ATEPC model checkpoints for Version:2.4.1.post1 (this version) **********
# [2024-07-10 15:37:31] (2.4.1.post1) Downloading checkpoint:english
# [2024-07-10 15:37:31] (2.4.1.post1) Notice: The pretrained model are used for testing, it is recommended to train the model on your own custom datasets
# [2024-07-10 15:37:31] (2.4.1.post1) Checkpoint already downloaded, skip
# [2024-07-10 15:37:31] (2.4.1.post1) Load aspect extractor from checkpoints/ATEPC_ENGLISH_CHECKPOINT/fast_lcf_atepc_English_cdw_apcacc_82.36_apcf1_81.89_atef1_75.43
# [2024-07-10 15:37:31] (2.4.1.post1) config: checkpoints/ATEPC_ENGLISH_CHECKPOINT/fast_lcf_atepc_English_cdw_apcacc_82.36_apcf1_81.89_atef1_75.43/fast_lcf_atepc.config
# [2024-07-10 15:37:31] (2.4.1.post1) state_dict: checkpoints/ATEPC_ENGLISH_CHECKPOINT/fast_lcf_atepc_English_cdw_apcacc_82.36_apcf1_81.89_atef1_75.43/fast_lcf_atepc.state_dict
# [2024-07-10 15:37:31] (2.4.1.post1) model: None
# [2024-07-10 15:37:31] (2.4.1.post1) tokenizer: checkpoints/ATEPC_ENGLISH_CHECKPOINT/fast_lcf_atepc_English_cdw_apcacc_82.36_apcf1_81.89_atef1_75.43/fast_lcf_atepc.tokenizer
# [2024-07-10 15:37:31] (2.4.1.post1) Set Model Device: cuda:0
# [2024-07-10 15:37:31] (2.4.1.post1) Device Name: NVIDIA GeForce GTX 1070
# /home/fra/.venv/nlp/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:562: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
result = aspect_extractor.predict(
    text=df_comments_only_eng_short['value'].to_list(),
    print_result=False,
    ignore_error=True,  # ignore an invalid example, if it is False, invalid examples will raise Exceptions
    eval_batch_size=64,
)
# Out:
# preparing ate inference dataloader: 100%|██████████| 45144/45144 [01:42<00:00, 440.35it/s]
# extracting aspect terms: 100%|██████████| 1411/1411 [34:02<00:00,  1.45s/it]
# preparing apc inference dataloader: 100%|██████████| 53730/53730 [02:49<00:00, 317.21it/s]
# classifying aspect sentiments: 100%|██████████| 1680/1680 [41:58<00:00,  1.50s/it]
# [2024-07-04 16:07:50] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json

# %%
result_everdell = aspect_extractor.predict(
    text=df_everdell_cleaned['value'].to_list(),
    print_result=False,
    ignore_error=True,  # ignore an invalid example, if it is False, invalid examples will raise Exceptions
    eval_batch_size=64,
)
# Out:
# preparing ate inference dataloader: 100%|██████████| 4571/4571 [00:09<00:00, 478.91it/s]
# extracting aspect terms: 100%|██████████| 72/72 [04:08<00:00,  3.46s/it]
# preparing apc inference dataloader: 100%|██████████| 6653/6653 [00:18<00:00, 367.33it/s]
# /home/fra/.venv/nlp/lib/python3.10/site-packages/pyabsa/tasks/AspectTermExtraction/prediction/aspect_extractor.py:593: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:274.)
#   lcf_cdm_vec = torch.tensor(
# classifying aspect sentiments: 100%|██████████| 104/104 [06:09<00:00,  3.55s/it]
# [2024-07-10 15:48:56] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json

# %%
result_uno = aspect_extractor.predict(
    text=df_uno_cleaned['value'].to_list(),
    print_result=False,
    ignore_error=True,  # ignore an invalid example, if it is False, invalid examples will raise Exceptions
    eval_batch_size=64,
)
# Out:
# preparing ate inference dataloader: 100%|██████████| 3492/3492 [00:04<00:00, 856.57it/s]
# extracting aspect terms: 100%|██████████| 55/55 [03:25<00:00,  3.73s/it]
# preparing apc inference dataloader: 100%|██████████| 3254/3254 [00:06<00:00, 499.92it/s]
# classifying aspect sentiments: 100%|██████████| 51/51 [02:55<00:00,  3.44s/it]
# [2024-07-10 15:57:19] (2.4.1.post1) The results of aspect term extraction have been saved in /home/fra/uni/nlp/project/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json

# %%
with open('/home/fra/uni/nlp/project/content/drive/MyDrive/Boardgames/pyabsa_aspect_extractor_result.pkl','wb') as f:
    pickle.dump(result, f)

# %%
with open('/home/fra/uni/nlp/project/content/drive/MyDrive/Boardgames/pyabsa_aspect_extractor_result.pkl','rb') as f:
    result = pickle.load(f)

# %%
game_aspects_pyabsa = {}
for id in df_boardgames_10['id']:
    game_comments = df_comments_only_eng_short[df_comments_only_eng_short['boardgame_id']==id]
    aspects = []
    polarities = []
    for i in game_comments.index:
        aspects += result[i]['aspect']
        polarities += result[i]['sentiment']
    game_aspects_pyabsa[f'{id}'] = (aspects,polarities)

# %%
aspects = []
polarities = []
for i in df_everdell_cleaned.index:
    aspects += result_everdell[i]['aspect']
    polarities += result_everdell[i]['sentiment']
game_aspects_pyabsa[f'199792'] = (aspects,polarities)

# %%
aspects = []
polarities = []
for i in df_uno_cleaned.index:
    aspects += result_uno[i]['aspect']
    polarities += result_uno[i]['sentiment']
game_aspects_pyabsa[f'2223'] = (aspects,polarities)

# %%
try:
    game_aspects_pyabsa
    with open('/home/fra/uni/nlp/project/content/drive/MyDrive/Boardgames/saved_game_aspects_pyabsa_dict.pkl','wb') as f:
        pickle.dump(game_aspects_pyabsa, f)
except NameError:
    print('loaded from storage')
    with open('/home/fra/uni/nlp/project/content/drive/MyDrive/Boardgames/saved_game_aspects_pyabsa_dict.pkl', 'rb') as f:
        game_aspects_pyabsa = pickle.load(f)
# Out:
# loaded from storage

# %%
extract_list(game_aspects_pyabsa, n_aspects=5, min_cutoff=25, lemmatization=True)
# Out:
# Brass: Birmingham (224517)
# ['game', 'games', 'Game', 'Games', 'Brass: Birmingham', 'brass', 'birmingham']
# 5
# Best: ['mechanic', 'interaction', 'design', 'player interaction', 'component']
# Worst: ['teach', 'time', 'rule', 'board', 'learn']
#
#
# Pandemic Legacy: Season 1 (161936)
# ['game', 'games', 'Game', 'Games', 'Pandemic Legacy: Season 1', 'pandemic', 'legacy', 'season', '1']
# 5
# Best: ['gaming', 'experience', 'playing', 'money', 'narrative']
# Worst: ['ending', 'replayability', 'card', 'rule', 'difficulty']
#
#
# Gloomhaven (174430)
# ['game', 'games', 'Game', 'Games', 'Gloomhaven', 'gloomhaven']
# 5
# Best: ['value', 'world', 'content', 'system', 'mechanic']
# Worst: ['set up', 'set', 'setup time', 'setup', 'tear down']
#
#
# Ark Nova (342942)
# ['game', 'games', 'Game', 'Games', 'Ark Nova', 'ark', 'nova']
# 5
# Best: ['theme', 'mechanic', 'gameplay', 'design', 'play']
# Worst: ['randomness', 'luck', 'hour', 'length', 'playtime']
#
#
# Twilight Imperium: Fourth Edition (233078)
# ['game', 'games', 'Game', 'Games', 'Twilight Imperium: Fourth Edition', 'twilight', 'imperium', 'fourth', 'edition']
# 5
# Best: ['faction', 'play', 'gameplay', 'expansion', 'table']
# Worst: ['hour', 'length', 'playtime', 'player', 'time']
#
#
# Dune: Imperium (316554)
# ['game', 'games', 'Game', 'Games', 'Dune: Imperium', 'dune', 'imperium']
# 5
# Best: ['immortality', 'mechanic', 'interaction', 'play', 'design']
# Worst: ['board', 'card', 'time', 'player', 'component']
#
#
# Terraforming Mars (167791)
# ['game', 'games', 'Game', 'Games', 'Terraforming Mars', 'terraforming', 'mars']
# 5
# Best: ['replayability', 'theme', 'engine building', 'engine builder', 'mechanic']
# Worst: ['hour', 'downtime', 'component quality', 'randomness', 'material']
#
#
# War of the Ring: Second Edition (115746)
# ['game', 'games', 'Game', 'Games', 'War of the Ring: Second Edition', 'war', 'of', 'the', 'ring', 'second', 'edition']
# 5
# Best: ['theme', 'design', 'gameplay', 'component', 'play']
# Worst: ['rulebook', 'setup', 'rule', 'time', 'dice']
#
#
# Star Wars: Rebellion (187645)
# ['game', 'games', 'Game', 'Games', 'Star Wars: Rebellion', 'star', 'wars', 'rebellion']
# 5
# Best: ['theme', 'component', 'mechanic', 'gameplay', 'design']
# Worst: ['hour', 'combat', 'length', 'playtime', 'dice']
#
#
# Gloomhaven: Jaws of the Lion (291457)
# ['game', 'games', 'Game', 'Games', 'Gloomhaven: Jaws of the Lion', 'gloomhaven', 'jaws', 'of', 'the', 'lion']
# 5
# Best: ['tutorial', 'book', 'price', 'play', 'dungeon']
# Worst: ['time', 'sticker', 'story', 'card', 'box']
#
#
# Everdell (199792)
# ['game', 'games', 'Game', 'Games', 'Everdell', 'everdell']
# 5
# Best: ['learn', 'artwork', 'art', 'theme', 'table presence']
# Worst: ['text', 'interaction', 'deck', 'player', 'resource']
#
#
# UNO (2223)
# ['game', 'games', 'Game', 'Games', 'UNO', 'uno']
# 5
# Best: ['learn', 'play', 'card game', 'kid', 'player']
# Worst: ['strategy', 'luck', 'rule', 'deck', 'card']

# %%
df_test = df_comments_only_eng_short[df_comments_only_eng_short['boardgame_id']==224517]['value']
for v in df_test[df_test.apply(lambda x: 'tea' in x.split(' '))].sample(20,replace=True):
    print(v)
# Out:
# Meh.  Not bad but I don’t get all the excitement about this game.  I didn’t really care for the “reset” midway through, either. A decent game but not my cup of tea I guess.
# It's a good game, just not my cup of tea for most game nights. Once in awhile is fine.
# It's a good game, just not my cup of tea for most game nights. Once in awhile is fine.
# Meh.  Not bad but I don’t get all the excitement about this game.  I didn’t really care for the “reset” midway through, either. A decent game but not my cup of tea I guess.
# It's a good game, just not my cup of tea for most game nights. Once in awhile is fine.
# It's a good game, just not my cup of tea for most game nights. Once in awhile is fine.
# Meh.  Not bad but I don’t get all the excitement about this game.  I didn’t really care for the “reset” midway through, either. A decent game but not my cup of tea I guess.
# It's a good game, just not my cup of tea for most game nights. Once in awhile is fine.
# Because the game is so popular lately i wanted to give it a shot. I started the game by choosing my actions by feel but i filled up these with thought later. I didn't understand the meaning of my choices till halfway of the first round. The game has great depth and some interesting tactical and strategical decisions. The theme is not my cup of tea but goes along with the game well. I don't think that it worth buying for my collection but if i asked to i will happily play it again.
# Meh.  Not bad but I don’t get all the excitement about this game.  I didn’t really care for the “reset” midway through, either. A decent game but not my cup of tea I guess.
# economic game, interesting but not my cup of tea
# economic game, interesting but not my cup of tea
# economic game, interesting but not my cup of tea
# Because the game is so popular lately i wanted to give it a shot. I started the game by choosing my actions by feel but i filled up these with thought later. I didn't understand the meaning of my choices till halfway of the first round. The game has great depth and some interesting tactical and strategical decisions. The theme is not my cup of tea but goes along with the game well. I don't think that it worth buying for my collection but if i asked to i will happily play it again.
# economic game, interesting but not my cup of tea
# It's a good game, just not my cup of tea for most game nights. Once in awhile is fine.
# It's a good game, just not my cup of tea for most game nights. Once in awhile is fine.
# Because the game is so popular lately i wanted to give it a shot. I started the game by choosing my actions by feel but i filled up these with thought later. I didn't understand the meaning of my choices till halfway of the first round. The game has great depth and some interesting tactical and strategical decisions. The theme is not my cup of tea but goes along with the game well. I don't think that it worth buying for my collection but if i asked to i will happily play it again.
# Because the game is so popular lately i wanted to give it a shot. I started the game by choosing my actions by feel but i filled up these with thought later. I didn't understand the meaning of my choices till halfway of the first round. The game has great depth and some interesting tactical and strategical decisions. The theme is not my cup of tea but goes along with the game well. I don't think that it worth buying for my collection but if i asked to i will happily play it again.
# economic game, interesting but not my cup of tea

# %%
srs_aspects.apply(lambda x:x.lower())
# Out:
# 0        clay coins
# 1              game
# 2          strategy
# 3       interaction
# 4               art
#            ...
# 4568           play
# 4569           game
# 4570      resources
# 4571           play
# 4572       learning
# Length: 4573, dtype: object

# %% [markdown]
# # Lemmatizer benchmark

# %%
import time
import spacy

# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# Example list of aspect terms
aspects = ["cards", "card", "gameplay", "playing"] * 1000  # Larger dataset for timing

# Measure the time taken by spaCy lemmatizer
start_time = time.time()
lemmatized_aspects_spacy = [nlp(aspect)[0].lemma_ for aspect in aspects]
spacy_time = time.time() - start_time

print(f"spaCy lemmatization time: {spacy_time:.4f} seconds")
# Out:
# spaCy lemmatization time: 15.1394 seconds

# %%
import time
from nltk.stem import WordNetLemmatizer

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()
lemmatizer.lemmatize(aspect)

# Example list of aspect terms
aspects = ["cards", "card", "gameplay", "playing"] * 1000  # Larger dataset for timing

# Measure the time taken by NLTK lemmatizer
start_time = time.time()
lemmatized_aspects_nltk = [lemmatizer.lemmatize(aspect) for aspect in aspects]
nltk_time = time.time() - start_time

print(f"NLTK lemmatization time: {nltk_time:.4f} seconds")
# Out:
# NLTK lemmatization time: 4.3462 seconds
